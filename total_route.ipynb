# %%
import pandas as pd
import numpy as np
import pprint

# CSV 파일 읽기
df = pd.read_csv('/content/drive/MyDrive/KHU-TON/최근접이웃_수도권.csv', encoding='cp949')

def remove_parentheses(text):
    return text.split('(')[0].strip()

df['출발역'] = df['출발역'].apply(remove_parentheses)
df['종착역'] = df['종착역'].apply(remove_parentheses)


# 그래프 딕셔너리 초기화
g = {}

# 데이터를 반복하면서 그래프 생성
for _, row in df.iterrows():
    station1 = row['출발역']
    station2 = row['종착역']
    distance = row['LENGTH']  # 거리 데이터 컬럼명은 확인 필요
    line = row['호선']  # 호선 정보 컬럼명은 확인 필요

    if station1 not in g:
        g[station1] = {}
    if station2 not in g:
        g[station2] = {}

    # 역간 거리와 호선 정보를 튜플로 저장
    g[station1][station2] = (distance, line)
    g[station2][station1] = (distance, line)  # 양방향 연결 가정

# 결과 출력
for station, connections in g.items():
    pp = pprint.PrettyPrinter(indent=4)

pp.pprint(g)
# Out:
# {   '4.19민주묘지': {'가오리': (0.9, '우이신설선'), '솔밭공원': (0.7, '우이신설선')},
#     '가능': {'녹양': (1.3, '서울1호선'), '의정부': (1.2, '서울1호선')},
#     '가락시장역': {   '경찰병원': (0.8, '서울3호선'),
#                  '문정': (0.9, '서울8호선'),
#                  '송파': (0.8, '서울8호선'),
#                  '수서역': (1.4, '서울3호선')},
#     '가산디지털단지': {   '남구로': (0.8, '서울7호선'),
#                    '독산': (2.0, '서울1호선'),
#                    '분기점': (1.1, '서울1호선'),
#                    '철산': (1.4, '서울7호선')},
#     '가양': {'양천향교': (1.3, '서울9호선'), '증미': (0.7, '서울9호선')},
#     '가오리': {'4.19민주묘지': (0.9, '우이신설선'), '화계': (0.8, '우이신설선')},
#     '가좌역': {   '디지털미디어시티': (1.7, '경의중앙선(수도권전철)'),
#                '신촌': (2.7, '경의중앙선(수도권전철)'),
#                '홍대입구역': (1.7, '경의중앙선(수도권전철)')},
#     '가천대': {'복정역': (2.4, '분당선'), '태평': (1.0, '분당선')},
#     '가평역': {   '가평역': (4.7, '경춘선(수도권전철)'),
#                '굴봉산': (4.7, '경춘선(수도권전철)'),
#                '상천': (7.1, '경춘선(수도권전철)')},
#     '갈매': {'별내': (1.4, '경춘선(수도권전철)'), '신내': (2.6, '경춘선(수도권전철)')},
#     '강남구청역': {   '선정릉역': (0.7, '분당선'),
#                  '압구정로데오': (1.2, '분당선'),
#                  '청담': (1.1, '서울7호선'),
#                  '학동': (0.9, '서울7호선')},
#     '강남대': {'기흥역': (1.044, '용인경전철'), '지석': (1.062, '용인경전철')},
#     '강남역': {'교대역': (1.2, '서울2호선'), '양재역': (1.5, '신분당선'), '역삼': (0.8, '서울2호선')},
#     '강동구청': {'몽촌토성': (1.6, '서울8호선'), '천호역': (0.9, '서울8호선')},
#     '강동역': {'길동': (0.9, '서울5호선'), '둔촌동': (1.2, '서울5호선'), '천호역': (0.8, '서울5호선')},
#     '강매': {'행신역': (0.9, '경의중앙선(수도권전철)'), '화전': (2.5, '경의중앙선(수도권전철)')},
#     '강변': {'구의': (0.9, '서울2호선'), '잠실나루역': (1.8, '서울2호선')},
#     '개롱': {'거여': (0.9, '서울5호선'), '오금역': (0.9, '서울5호선')},
#     '개봉': {'구일': (1.0, '서울1호선'), '오류동': (1.3, '서울1호선')},
#     '개포동': {'구룡': (0.7, '분당선'), '대모산입구': (0.6, '분당선')},
#     '개화': {'김포공항역': (3.6, '서울9호선')},
#     '개화산': {'김포공항역': (1.2, '서울5호선'), '방화': (0.9, '서울5호선')},
#     '거여': {'개롱': (0.9, '서울5호선'), '마천': (0.9, '서울5호선')},
#     '건대입구역': {   '구의': (1.6, '서울2호선'),
#                  '뚝섬유원지': (1.0, '서울7호선'),
#                  '성수역': (1.2, '서울2호선'),
#                  '어린이대공원': (0.8, '서울7호선')},
#     '걸포북변': {'사우': (1.73, '김포골드라인'), '운양': (3.47, '김포골드라인')},
#     '경기광주': {'삼동': (4.9, '경강선(수도권전철)'), '초월': (5.0, '경강선(수도권전철)')},
#     '경기도청북부청사': {'새말': (0.716, '의정부경전철'), '효자': (0.63, '의정부경전철')},
#     '경마공원': {'대공원': (0.9, '서울4호선'), '선바위': (1.0, '서울4호선')},
#     '경복궁': {'독립문': (1.6, '서울3호선'), '안국': (1.1, '서울3호선')},
#     '경전철의정부': {'범골': (0.949, '의정부경전철'), '의정부시청': (0.92, '의정부경전철')},
#     '경찰병원': {'가락시장역': (0.8, '서울3호선'), '오금역': (0.8, '서울3호선')},
#     '고덕': {'명일': (1.2, '서울5호선'), '상일동': (1.1, '서울5호선')},
#     '고려대': {'안암': (0.8, '서울6호선'), '월곡': (1.4, '서울6호선')},
#     '고속터미널역': {   '교대역': (1.6, '서울3호선'),
#                   '내방': (2.2, '서울7호선'),
#                   '반포': (0.9, '서울7호선'),
#                   '사평': (1.1, '서울9호선'),
#                   '신반포': (0.8, '서울9호선'),
#                   '잠원': (1.2, '서울3호선')},
#     '고잔': {'중앙': (1.4, '서울4호선'), '초지': (1.5, '서울4호선')},
#     '고진': {'보평': (1.75, '용인경전철'), '운동장,송담대': (0.935, '용인경전철')},
#     '고촌역': {'김포공항역': (5.9, '김포골드라인'), '풍무': (3.6, '김포골드라인')},
#     '곡산': {'대곡역': (1.7, '경의중앙선(수도권전철)'), '백마': (1.6, '경의중앙선(수도권전철)')},
#     '곤제': {'어룡': (0.904, '의정부경전철'), '효자': (0.772, '의정부경전철')},
#     '곤지암': {'신둔도예촌': (6.8, '경강선(수도권전철)'), '초월': (4.9, '경강선(수도권전철)')},
#     '공덕역': {   '대흥': (0.9, '서울6호선'),
#                '마포': (0.8, '서울5호선'),
#                '서강대': (1.9, '경의중앙선(수도권전철)'),
#                '서울역': (3.3, '공항철도'),
#                '애오개': (1.1, '서울5호선'),
#                '홍대입구역': (2.8, '공항철도'),
#                '효창공원앞': (1.0, '경의중앙선(수도권전철)')},
#     '공릉': {'태릉입구역': (0.8, '서울7호선'), '하계': (1.3, '서울7호선')},
#     '공항시장': {'김포공항역': (0.8, '서울9호선'), '신방화': (0.8, '서울9호선')},
#     '과천': {'대공원': (1.0, '서울4호선'), '정부과천청사': (1.0, '서울4호선')},
#     '관악': {'석수': (1.9, '서울1호선'), '안양역': (2.4, '서울1호선')},
#     '광교': {'광교중앙': (2.0, '신분당선')},
#     '광교중앙': {'광교': (2.0, '신분당선'), '상현': (2.4, '신분당선')},
#     '광나루': {'아차산': (1.5, '서울5호선'), '천호역': (2.0, '서울5호선')},
#     '광명사거리': {'천왕': (1.7, '서울7호선'), '철산': (1.3, '서울7호선')},
#     '광명역': {'분기': (2.8, '서울1호선')},
#     '광운대역': {   '상봉역': (4.3, '경춘선(수도권전철)'),
#                 '석계역': (1.1, '서울1호선'),
#                 '월계': (1.1, '서울1호선')},
#     '광화문': {'서대문': (1.1, '서울5호선'), '종로3가역': (1.2, '서울5호선')},
#     '광흥창': {'대흥': (1.0, '서울6호선'), '상수': (0.9, '서울6호선')},
#     '교대역': {   '강남역': (1.2, '서울2호선'),
#                '고속터미널역': (1.6, '서울3호선'),
#                '남부터미널': (0.9, '서울3호선'),
#                '서초': (0.7, '서울2호선')},
#     '구래': {'마산역': (1.6, '김포골드라인'), '양촌': (1.4, '김포골드라인')},
#     '구로디지털단지': {'대림역': (1.1, '서울2호선'), '신대방': (1.1, '서울2호선')},
#     '구로역': {'분기점': (1.0, '서울1호선'), '신도림역': (1.1, '서울1호선')},
#     '구룡': {'개포동': (0.7, '분당선'), '도곡역': (0.6, '분당선')},
#     '구리': {'도농': (1.7, '경의중앙선(수도권전철)'), '양원': (3.2, '경의중앙선(수도권전철)')},
#     '구반포': {'동작역': (1.0, '서울9호선'), '신반포': (0.7, '서울9호선')},
#     '구산': {'연신내역': (0.9, '서울6호선'), '응암': (1.5, '서울6호선')},
#     '구성': {'보정': (1.6, '분당선'), '신갈': (1.6, '분당선')},
#     '구의': {'강변': (0.9, '서울2호선'), '건대입구역': (1.6, '서울2호선')},
#     '구일': {'개봉': (1.0, '서울1호선'), '분기점': (0.4, '서울1호선')},
#     '구파발': {'연신내역': (2.0, '서울3호선'), '지축': (1.5, '서울3호선')},
#     '국수': {'신원': (2.9, '경의중앙선(수도권전철)'), '아신': (4.1, '경의중앙선(수도권전철)')},
#     '국회의사당': {'당산역': (1.5, '서울9호선'), '여의도역': (0.9, '서울9호선')},
#     '군자역': {   '아차산': (1.0, '서울5호선'),
#                '어린이대공원': (1.1, '서울7호선'),
#                '장한평': (1.5, '서울5호선'),
#                '중곡': (1.1, '서울7호선')},
#     '군포': {'금정역': (2.2, '서울1호선'), '당정': (1.6, '서울1호선')},
#     '굴봉산': {'가평역': (4.7, '경춘선(수도권전철)')},
#     '굽은다리': {'길동': (0.8, '서울5호선'), '명일': (0.7, '서울5호선')},
#     '금곡': {'사릉역': (3.6, '경춘선(수도권전철)'), '평내호평역': (4.0, '경춘선(수도권전철)')},
#     '금릉': {'금촌': (2.1, '경의중앙선(수도권전철)'), '운정': (3.1, '경의중앙선(수도권전철)')},
#     '금정역': {   '군포': (2.2, '서울1호선'),
#                '명학': (1.4, '서울1호선'),
#                '범계': (2.6, '서울4호선'),
#                '산본': (2.3, '서울4호선')},
#     '금천구청역': {'독산': (1.2, '서울1호선'), '분기': (1.1, '서울1호선')},
#     '금촌': {'금릉': (2.1, '경의중앙선(수도권전철)'), '월롱': (4.1, '경의중앙선(수도권전철)')},
#     '금호': {'약수역': (0.8, '서울3호선'), '옥수역': (0.8, '서울3호선')},
#     '기흥역': {'강남대': (1.044, '용인경전철'), '상갈': (1.9, '분당선'), '신갈': (1.4, '분당선')},
#     '길동': {'강동역': (0.9, '서울5호선'), '굽은다리': (0.8, '서울5호선')},
#     '길음': {'미아사거리': (1.3, '서울4호선'), '성신여대입구': (1.4, '서울4호선')},
#     '김량장': {'명지대': (0.755, '용인경전철'), '운동장,송담대': (0.945, '용인경전철')},
#     '김포공항역': {   '개화': (3.6, '서울9호선'),
#                  '개화산': (1.2, '서울5호선'),
#                  '고촌역': (5.9, '김포골드라인'),
#                  '공항시장': (0.8, '서울9호선'),
#                  '김포공항역': (6.6, '공항철도'),
#                  '마곡나루역': (2.3, '공항철도'),
#                  '송정': (1.2, '서울5호선')},
#     '까치산역': {   '신정': (1.3, '서울5호선'),
#                 '신정네거리': (1.4, '서울2호선'),
#                 '화곡': (1.2, '서울5호선')},
#     '까치울': {'부천종합운동장': (1.2, '서울7호선'), '온수역': (2.2, '서울7호선')},
#     '낙성대': {'사당역': (1.7, '서울2호선'), '서울대입구': (1.0, '서울2호선')},
#     '남구로': {'가산디지털단지': (0.8, '서울7호선'), '대림역': (1.1, '서울7호선')},
#     '남부터미널': {'교대역': (0.9, '서울3호선'), '양재역': (1.8, '서울3호선')},
#     '남성': {'숭실대입구': (2.0, '서울7호선'), '총신대입구역': (1.0, '서울7호선')},
#     '남영': {'서울역': (1.7, '서울1호선'), '용산역': (1.5, '서울1호선')},
#     '남태령': {'사당역': (1.6, '서울4호선'), '선바위': (2.0, '서울4호선')},
#     '남한산성입구': {'단대오거리': (0.8, '서울8호선'), '산성': (1.3, '서울8호선')},
#     '내방': {'고속터미널역': (2.2, '서울7호선'), '총신대입구역': (1.0, '서울7호선')},
#     '노들': {'노량진역': (1.1, '서울9호선'), '흑석': (1.1, '서울9호선')},
#     '노량진역': {   '노들': (1.1, '서울9호선'),
#                 '대방': (1.5, '서울1호선'),
#                 '분기점': (1.8, '서울1호선'),
#                 '샛강': (1.2, '서울9호선')},
#     '노원역': {   '마들': (1.2, '서울7호선'),
#                '상계': (1.0, '서울4호선'),
#                '중계': (1.1, '서울7호선'),
#                '창동역': (1.4, '서울4호선')},
#     '녹번': {'불광역': (1.1, '서울3호선'), '홍제': (1.6, '서울3호선')},
#     '녹사평': {'삼각지역': (1.1, '서울6호선'), '이태원': (0.8, '서울6호선')},
#     '녹양': {'가능': (1.3, '서울1호선'), '양주': (1.6, '서울1호선')},
#     '녹천': {'월계': (1.4, '서울1호선'), '창동역': (1.0, '서울1호선')},
#     '논현': {'반포': (0.9, '서울7호선'), '학동': (1.0, '서울7호선')},
#     '능곡': {'대곡역': (1.8, '경의중앙선(수도권전철)'), '행신역': (1.5, '경의중앙선(수도권전철)')},
#     '단대오거리': {'남한산성입구': (0.8, '서울8호선'), '신흥': (0.8, '서울8호선')},
#     '달미': {'선부': (1.6, '소사~원시'), '시흥능곡': (2.4, '소사~원시')},
#     '달월': {'오이도역': (2.1, '수인선'), '월곶': (1.5, '수인선')},
#     '답십리': {'마장': (1.0, '서울5호선'), '장한평': (1.2, '서울5호선')},
#     '당고개': {'상계': (1.2, '서울4호선')},
#     '당산역': {   '국회의사당': (1.5, '서울9호선'),
#                '선유도': (1.0, '서울9호선'),
#                '영등포구청역': (1.1, '서울2호선'),
#                '합정역': (2.0, '서울2호선')},
#     '당정': {'군포': (1.6, '서울1호선'), '의왕': (2.6, '서울1호선')},
#     '대곡역': {   '곡산': (1.7, '경의중앙선(수도권전철)'),
#                '능곡': (1.8, '경의중앙선(수도권전철)'),
#                '백석': (2.5, '서울3호선'),
#                '화정': (2.1, '서울3호선')},
#     '대공원': {'경마공원': (0.9, '서울4호선'), '과천': (1.0, '서울4호선')},
#     '대광리': {'신탄리': (5.6, '서울1호선')},
#     '대림역': {   '구로디지털단지': (1.1, '서울2호선'),
#                '남구로': (1.1, '서울7호선'),
#                '신도림역': (1.8, '서울2호선'),
#                '신풍': (1.4, '서울7호선')},
#     '대모산입구': {'개포동': (0.6, '분당선'), '수서역': (3.0, '분당선')},
#     '대방': {'노량진역': (1.5, '서울1호선'), '신길역': (0.8, '서울1호선')},
#     '대성리': {'마석역': (7.4, '경춘선(수도권전철)'), '청평역': (7.5, '경춘선(수도권전철)')},
#     '대야미': {'반월': (2.0, '서울4호선'), '수리산': (2.6, '서울4호선')},
#     '대청': {'일원': (1.2, '서울3호선'), '학여울': (0.9, '서울3호선')},
#     '대치': {'도곡역': (0.8, '서울3호선'), '학여울': (0.8, '서울3호선')},
#     '대화': {'주엽': (1.4, '서울3호선')},
#     '대흥': {'공덕역': (0.9, '서울6호선'), '광흥창': (1.0, '서울6호선')},
#     '덕계': {'덕정': (2.9, '서울1호선'), '양주': (5.3, '서울1호선')},
#     '덕소역': {'도심': (1.5, '경의중앙선(수도권전철)'), '양정': (2.3, '경의중앙선(수도권전철)')},
#     '덕정': {'덕계': (2.9, '서울1호선'), '지행': (5.6, '서울1호선')},
#     '도곡역': {   '구룡': (0.6, '분당선'),
#                '대치': (0.8, '서울3호선'),
#                '매봉': (0.8, '서울3호선'),
#                '한티': (0.7, '분당선')},
#     '도농': {'구리': (1.7, '경의중앙선(수도권전철)'), '양정': (3.7, '경의중앙선(수도권전철)')},
#     '도라산': {'임진강': (3.7, '경의중앙선(수도권전철)')},
#     '도림천': {'신도림역': (1.0, '서울2호선'), '양천구청': (1.7, '서울2호선')},
#     '도봉': {'도봉산역': (1.2, '서울1호선'), '방학': (1.3, '서울1호선')},
#     '도봉산역': {   '도봉': (1.2, '서울1호선'),
#                 '망월사': (2.3, '서울1호선'),
#                 '수락산': (1.6, '서울7호선'),
#                 '장암': (1.4, '서울7호선')},
#     '도심': {'덕소역': (1.5, '경의중앙선(수도권전철)'), '팔당': (4.2, '경의중앙선(수도권전철)')},
#     '독립문': {'경복궁': (1.6, '서울3호선'), '무악재': (1.1, '서울3호선')},
#     '독바위': {'불광역': (0.9, '서울6호선'), '연신내역': (1.4, '서울6호선')},
#     '독산': {'가산디지털단지': (2.0, '서울1호선'), '금천구청역': (1.2, '서울1호선')},
#     '돌곶이': {'상월곡': (0.8, '서울6호선'), '석계역': (1.0, '서울6호선')},
#     '동대문': {'동묘앞역': (0.6, '서울1호선'), '종로5가': (0.8, '서울1호선')},
#     '동대문역': {'동대문역사문화공원': (0.7, '서울4호선'), '혜화': (1.5, '서울4호선')},
#     '동대문역사문화공원': {   '동대문역': (0.7, '서울4호선'),
#                      '신당역': (0.9, '서울2호선'),
#                      '을지로4가역': (0.9, '서울5호선'),
#                      '청구역': (0.9, '서울5호선'),
#                      '충무로역': (1.3, '서울4호선')},
#     '동대입구': {'약수역': (0.7, '서울3호선'), '충무로역': (0.9, '서울3호선')},
#     '동두천역': {'보산': (1.6, '서울1호선'), '소요산역': (2.5, '서울1호선')},
#     '동두천중앙': {'보산': (1.4, '서울1호선'), '지행': (1.0, '서울1호선')},
#     '동묘앞역': {   '동대문': (0.6, '서울1호선'),
#                 '신당역': (0.6, '서울6호선'),
#                 '신설동역': (0.7, '서울1호선'),
#                 '창신': (0.9, '서울6호선')},
#     '동백': {'어정': (1.185, '용인경전철'), '초당': (1.097, '용인경전철')},
#     '동오': {'새말': (0.739, '의정부경전철'), '의정부중앙': (0.703, '의정부경전철')},
#     '동작역': {   '구반포': (1.0, '서울9호선'),
#                '이촌역': (2.7, '서울4호선'),
#                '총신대입구역': (1.8, '서울4호선'),
#                '흑석': (1.4, '서울9호선')},
#     '동천': {'미금역': (1.6, '신분당선'), '수지구청': (2.1, '신분당선')},
#     '동탄': {'수서역': (32.6, nan), '지제역': (21.0, nan)},
#     '둔전': {'보평': (1.027, '용인경전철'), '전대,에버랜드': (2.626, '용인경전철')},
#     '둔촌동': {'강동역': (1.2, '서울5호선'), '올림픽공원': (1.4, '서울5호선')},
#     '둔촌오륜': {'올림픽공원역': (1.0, '서울지하철9호선'), '중앙보훈병원': (1.7, '서울지하철9호선')},
#     '등촌': {'염창': (0.9, '서울9호선'), '증미': (1.0, '서울9호선')},
#     '디지털미디어시티': {   '가좌역': (1.7, '경의중앙선(수도권전철)'),
#                     '분기': (2.3, '공항철도'),
#                     '수색': (0.6, '경의중앙선(수도권전철)'),
#                     '월드컵경기장': (0.8, '서울6호선'),
#                     '증산': (1.1, '서울6호선'),
#                     '홍대입구역': (3.4, '공항철도')},
#     '뚝섬': {'성수역': (0.8, '서울2호선'), '한양대': (1.1, '서울2호선')},
#     '뚝섬유원지': {'건대입구역': (1.0, '서울7호선'), '청담': (2.0, '서울7호선')},
#     '마곡': {'발산': (1.2, '서울5호선'), '송정': (1.1, '서울5호선')},
#     '마곡나루': {'신방화': (0.9, '서울9호선'), '양천향교': (1.4, '서울9호선')},
#     '마곡나루역': {'김포공항역': (2.3, '공항철도'), '분기': (6.3, '공항철도')},
#     '마두': {'백석': (1.4, '서울3호선'), '정발산': (0.9, '서울3호선')},
#     '마들': {'노원역': (1.2, '서울7호선'), '수락산': (1.4, '서울7호선')},
#     '마산역': {'구래': (1.6, '김포골드라인'), '장기': (2.6, '김포골드라인')},
#     '마석역': {'대성리': (7.4, '경춘선(수도권전철)'), '천마산': (2.2, '경춘선(수도권전철)')},
#     '마장': {'답십리': (1.0, '서울5호선'), '왕십리역': (0.7, '서울5호선')},
#     '마천': {'거여': (0.9, '서울5호선')},
#     '마포': {'공덕역': (0.8, '서울5호선'), '여의나루': (1.8, '서울5호선')},
#     '마포구청': {'망원': (1.0, '서울6호선'), '월드컵경기장': (0.8, '서울6호선')},
#     '망우역': {   '상봉역': (0.6, '경춘선(수도권전철)'),
#                '신내': (2.1, '경춘선(수도권전철)'),
#                '양원': (1.7, '경의중앙선(수도권전철)')},
#     '망원': {'마포구청': (1.0, '서울6호선'), '합정역': (0.8, '서울6호선')},
#     '망월사': {'도봉산역': (2.3, '서울1호선'), '회룡역': (1.4, '서울1호선')},
#     '망포': {'매탄권선': (1.8, '분당선'), '영통': (1.5, '분당선')},
#     '매교': {'수원시청': (1.4, '분당선'), '수원역': (1.5, '분당선')},
#     '매봉': {'도곡역': (0.8, '서울3호선'), '양재역': (1.2, '서울3호선')},
#     '매탄권선': {'망포': (1.8, '분당선'), '수원시청': (1.4, '분당선')},
#     '먹골': {'중화': (0.9, '서울7호선'), '태릉입구역': (0.9, '서울7호선')},
#     '면목': {'사가정': (0.9, '서울7호선'), '상봉역': (0.8, '서울7호선')},
#     '명동': {'충무로역': (0.7, '서울4호선'), '회현': (0.7, '서울4호선')},
#     '명일': {'고덕': (1.2, '서울5호선'), '굽은다리': (0.7, '서울5호선')},
#     '명지대': {'김량장': (0.755, '용인경전철'), '시청,용인대': (1.034, '용인경전철')},
#     '명학': {'금정역': (1.4, '서울1호선'), '안양역': (2.2, '서울1호선')},
#     '모란역': {'수진': (1.0, '서울8호선'), '야탑': (2.3, '분당선'), '태평': (0.9, '분당선')},
#     '목동': {'신정': (0.8, '서울5호선'), '오목교': (0.9, '서울5호선')},
#     '몽촌토성': {'강동구청': (1.6, '서울8호선'), '잠실역': (0.8, '서울8호선')},
#     '무악재': {'독립문': (1.1, '서울3호선'), '홍제': (0.9, '서울3호선')},
#     '문래': {'신도림역': (1.2, '서울2호선'), '영등포구청역': (0.9, '서울2호선')},
#     '문산': {'운천': (3.7, '경의중앙선(수도권전철)'), '파주': (4.4, '경의중앙선(수도권전철)')},
#     '문정': {'가락시장역': (0.9, '서울8호선'), '장지': (0.9, '서울8호선')},
#     '미금역': {'동천': (1.6, '신분당선'), '오리': (1.1, '분당선'), '정자역': (1.9, '신분당선')},
#     '미아': {'미아사거리': (1.5, '서울4호선'), '수유': (1.4, '서울4호선')},
#     '미아사거리': {'길음': (1.3, '서울4호선'), '미아': (1.5, '서울4호선')},
#     '반월': {'대야미': (2.0, '서울4호선'), '상록수': (3.7, '서울4호선')},
#     '반포': {'고속터미널역': (0.9, '서울7호선'), '논현': (0.9, '서울7호선')},
#     '발곡': {'회룡역': (0.833, '의정부경전철')},
#     '발산': {'마곡': (1.2, '서울5호선'), '우장산': (1.1, '서울5호선')},
#     '방배': {'사당역': (1.6, '서울2호선'), '서초': (1.7, '서울2호선')},
#     '방이': {'오금역': (0.9, '서울5호선'), '올림픽공원': (0.9, '서울5호선')},
#     '방학': {'도봉': (1.3, '서울1호선'), '창동역': (1.7, '서울1호선')},
#     '방화': {'개화산': (0.9, '서울5호선')},
#     '백마': {'곡산': (1.6, '경의중앙선(수도권전철)'), '풍산': (1.7, '경의중앙선(수도권전철)')},
#     '백석': {'대곡역': (2.5, '서울3호선'), '마두': (1.4, '서울3호선')},
#     '버티고개': {'약수역': (0.7, '서울6호선'), '한강진': (1.0, '서울6호선')},
#     '범계': {'금정역': (2.6, '서울4호선'), '평촌': (1.3, '서울4호선')},
#     '범골': {'경전철의정부': (0.949, '의정부경전철'), '회룡역': (0.615, '의정부경전철')},
#     '별내': {'갈매': (1.4, '경춘선(수도권전철)'), '퇴계원역': (1.6, '경춘선(수도권전철)')},
#     '병점역': {'서동탄': (2.2, '서울1호선'), '세류': (4.3, '서울1호선'), '세마': (2.4, '서울1호선')},
#     '보라매': {'신대방삼거리': (0.8, '서울7호선'), '신풍': (0.9, '서울7호선')},
#     '보문역': {   '성신여대입구': (0.9, '우이신설선'),
#                '신설동역': (1.0, '우이신설선'),
#                '안암': (0.9, '서울6호선'),
#                '창신': (0.8, '서울6호선')},
#     '보산': {'동두천역': (1.6, '서울1호선'), '동두천중앙': (1.4, '서울1호선')},
#     '보정': {'구성': (1.6, '분당선'), '죽전': (1.3, '분당선')},
#     '보평': {'고진': (1.75, '용인경전철'), '둔전': (1.027, '용인경전철')},
#     '복정역': {   '가천대': (2.4, '분당선'),
#                '산성': (2.7, '서울8호선'),
#                '수서역': (3.2, '분당선'),
#                '장지': (0.9, '서울8호선')},
#     '봉은사': {'삼성중앙': (0.8, '서울9호선'), '종합운동장역': (1.4, '서울9호선')},
#     '봉천': {'서울대입구': (1.0, '서울2호선'), '신림': (1.1, '서울2호선')},
#     '봉화산': {'신내역': (1.3, '서울6호선'), '화랑대': (0.7, '서울6호선')},
#     '부발': {'세종대왕릉': (8.3, '경강선(수도권전철)'), '이천': (4.5, '경강선(수도권전철)')},
#     '부천': {'소사': (1.1, '서울1호선'), '중동': (1.7, '서울1호선')},
#     '부천시청': {'상동': (1.1, '서울7호선'), '신중동': (1.1, '서울7호선')},
#     '부천종합운동장': {'까치울': (1.2, '서울7호선'), '춘의': (0.9, '서울7호선')},
#     '북한산보국문': {'솔샘': (1.2, '우이신설선'), '정릉': (1.2, '우이신설선')},
#     '북한산우이': {'솔밭공원': (0.8, '우이신설선')},
#     '분기': {   '광명역': (2.8, '서울1호선'),
#               '금천구청역': (1.1, '서울1호선'),
#               '디지털미디어시티': (2.3, '공항철도'),
#               '마곡나루역': (6.3, '공항철도'),
#               '분기': (2.2, nan),
#               '석수': (1.2, '서울1호선'),
#               '수색': (1.7, '경의중앙선(수도권전철)'),
#               '지제역': (7.5, nan),
#               '화전': (1.7, '경의중앙선(수도권전철)')},
#     '분기점': {   '가산디지털단지': (1.1, '서울1호선'),
#                '구로역': (1.0, '서울1호선'),
#                '구일': (0.4, '서울1호선'),
#                '노량진역': (1.8, '서울1호선'),
#                '분기점': (1.2, '경의중앙선(수도권전철)'),
#                '용산역': (0.8, '경의중앙선(수도권전철)'),
#                '이촌역': (1.1, '경의중앙선(수도권전철)')},
#     '분당기지': {'오리': (2.3, nan)},
#     '불광역': {   '녹번': (1.1, '서울3호선'),
#                '독바위': (0.9, '서울6호선'),
#                '역촌': (0.8, '서울6호선'),
#                '연신내역': (1.3, '서울3호선')},
#     '사가정': {'면목': (0.9, '서울7호선'), '용마산': (0.8, '서울7호선')},
#     '사당역': {   '낙성대': (1.7, '서울2호선'),
#                '남태령': (1.6, '서울4호선'),
#                '방배': (1.6, '서울2호선'),
#                '총신대입구역': (1.1, '서울4호선')},
#     '사릉역': {'금곡': (3.6, '경춘선(수도권전철)'), '퇴계원역': (3.3, '경춘선(수도권전철)')},
#     '사우': {'걸포북변': (1.73, '김포골드라인'), '풍무': (1.6, '김포골드라인')},
#     '사평': {'고속터미널역': (1.1, '서울9호선'), '신논현': (0.9, '서울9호선')},
#     '산본': {'금정역': (2.3, '서울4호선'), '수리산': (1.1, '서울4호선')},
#     '산성': {'남한산성입구': (1.3, '서울8호선'), '복정역': (2.7, '서울8호선')},
#     '삼가': {'시청,용인대': (1.045, '용인경전철'), '초당': (2.591, '용인경전철')},
#     '삼각지역': {   '녹사평': (1.1, '서울6호선'),
#                 '숙대입구': (1.2, '서울4호선'),
#                 '신용산': (0.7, '서울4호선'),
#                 '효창공원앞': (1.2, '서울6호선')},
#     '삼동': {'경기광주': (4.9, '경강선(수도권전철)'), '이매역': (6.9, '경강선(수도권전철)')},
#     '삼성': {'선릉역': (1.3, '서울2호선'), '종합운동장역': (1.0, '서울2호선')},
#     '삼성중앙': {'봉은사': (0.8, '서울9호선'), '선정릉역': (0.8, '서울9호선')},
#     '삼송': {'원흥': (2.1, '서울3호선'), '지축': (1.7, '서울3호선')},
#     '삼양': {'삼양사거리': (0.7, '우이신설선'), '화계': (0.8, '우이신설선')},
#     '삼양사거리': {'삼양': (0.7, '우이신설선'), '솔샘': (0.8, '우이신설선')},
#     '삼전': {'석촌고분': (0.8, '서울지하철9호선'), '종합운동장역': (1.4, '서울지하철9호선')},
#     '상갈': {'기흥역': (1.9, '분당선'), '청명': (2.8, '분당선')},
#     '상계': {'노원역': (1.0, '서울4호선'), '당고개': (1.2, '서울4호선')},
#     '상도': {'숭실대입구': (0.9, '서울7호선'), '장승배기': (0.9, '서울7호선')},
#     '상동': {'부천시청': (1.1, '서울7호선')},
#     '상록수': {'반월': (3.7, '서울4호선'), '한대앞': (1.5, '서울4호선')},
#     '상봉역': {   '광운대역': (4.3, '경춘선(수도권전철)'),
#                '망우역': (0.6, '경춘선(수도권전철)'),
#                '면목': (0.8, '서울7호선'),
#                '중랑역': (0.8, '경춘선(수도권전철)'),
#                '중화': (1.0, '서울7호선')},
#     '상수': {'광흥창': (0.9, '서울6호선'), '합정역': (0.8, '서울6호선')},
#     '상왕십리': {'신당역': (0.9, '서울2호선'), '왕십리역': (0.8, '서울2호선')},
#     '상월곡': {'돌곶이': (0.8, '서울6호선'), '월곡': (0.8, '서울6호선')},
#     '상일동': {'고덕': (1.1, '서울5호선')},
#     '상천': {'가평역': (7.1, '경춘선(수도권전철)'), '청평역': (4.8, '경춘선(수도권전철)')},
#     '상현': {'광교중앙': (2.4, '신분당선'), '성복': (2.1, '신분당선')},
#     '새말': {'경기도청북부청사': (0.716, '의정부경전철'), '동오': (0.739, '의정부경전철')},
#     '새절': {'응암': (0.9, '서울6호선'), '증산': (0.9, '서울6호선')},
#     '샛강': {'노량진역': (1.2, '서울9호선'), '여의도역': (0.8, '서울9호선')},
#     '서강대': {'공덕역': (1.9, '경의중앙선(수도권전철)'), '홍대입구역': (0.9, '경의중앙선(수도권전철)')},
#     '서대문': {'광화문': (1.1, '서울5호선'), '충정로역': (0.7, '서울5호선')},
#     '서동탄': {'병점역': (2.2, '서울1호선')},
#     '서빙고': {'이촌역': (1.7, '경의중앙선(수도권전철)'), '한남': (1.9, '경의중앙선(수도권전철)')},
#     '서울대입구': {'낙성대': (1.0, '서울2호선'), '봉천': (1.0, '서울2호선')},
#     '서울숲': {'압구정로데오': (1.9, '분당선'), '왕십리역': (2.2, '분당선')},
#     '서울역': {   '공덕역': (3.3, '공항철도'),
#                '남영': (1.7, '서울1호선'),
#                '숙대입구': (1.0, '서울4호선'),
#                '시청역': (1.1, '서울1호선'),
#                '신촌': (3.1, '경의중앙선(수도권전철)'),
#                '회현': (0.9, '서울4호선')},
#     '서정리역': {'송탄': (2.2, '서울1호선'), '지제역': (4.8, '서울1호선')},
#     '서초': {'교대역': (0.7, '서울2호선'), '방배': (1.7, '서울2호선')},
#     '서현': {'수내': (1.1, '분당선'), '이매역': (1.4, '분당선')},
#     '석계역': {   '광운대역': (1.1, '서울1호선'),
#                '돌곶이': (1.0, '서울6호선'),
#                '신이문': (1.4, '서울1호선'),
#                '태릉입구역': (0.8, '서울6호선')},
#     '석불': {'지평역': (2.9, '경의중앙선(수도권전철)')},
#     '석수': {'관악': (1.9, '서울1호선'), '분기': (1.2, '서울1호선')},
#     '석촌': {'송파': (0.9, '서울8호선'), '잠실역': (1.2, '서울8호선')},
#     '석촌고분': {'삼전': (0.8, '서울지하철9호선'), '석촌역': (1.0, '서울지하철9호선')},
#     '석촌역': {'석촌고분': (1.0, '서울지하철9호선'), '송파나루': (0.8, '서울지하철9호선')},
#     '선릉역': {   '삼성': (1.3, '서울2호선'),
#                '선정릉역': (0.7, '분당선'),
#                '역삼': (1.2, '서울2호선'),
#                '한티': (1.0, '분당선')},
#     '선바위': {'경마공원': (1.0, '서울4호선'), '남태령': (2.0, '서울4호선')},
#     '선부': {'달미': (1.6, '소사~원시'), '초지역': (1.7, '소사~원시')},
#     '선유도': {'당산역': (1.0, '서울9호선'), '신목동': (1.2, '서울9호선')},
#     '선정릉역': {   '강남구청역': (0.7, '분당선'),
#                 '삼성중앙': (0.8, '서울9호선'),
#                 '선릉역': (0.7, '분당선'),
#                 '언주': (0.9, '서울9호선')},
#     '성균관대': {'의왕': (2.9, '서울1호선'), '화서': (2.6, '서울1호선')},
#     '성복': {'상현': (2.1, '신분당선'), '수지구청': (1.7, '신분당선')},
#     '성수역': {   '건대입구역': (1.2, '서울2호선'),
#                '뚝섬': (0.8, '서울2호선'),
#                '용답': (2.3, '서울2호선')},
#     '성신여대입구': {   '길음': (1.4, '서울4호선'),
#                   '보문역': (0.9, '우이신설선'),
#                   '정릉': (1.2, '우이신설선'),
#                   '한성대입구': (1.0, '서울4호선')},
#     '세류': {'병점역': (4.3, '서울1호선'), '수원역': (2.9, '서울1호선')},
#     '세마': {'병점역': (2.4, '서울1호선'), '오산대': (2.7, '서울1호선')},
#     '세종대왕릉': {'부발': (8.3, '경강선(수도권전철)'), '여주': (5.4, '경강선(수도권전철)')},
#     '소사': {'부천': (1.1, '서울1호선'), '역곡': (1.5, '서울1호선')},
#     '소사역': {'소새울': (1.7, '소사~원시')},
#     '소새울': {'소사역': (1.7, '소사~원시'), '시흥대야': (2.1, '소사~원시')},
#     '소요산역': {'동두천역': (2.5, '서울1호선'), '초성리': (4.1, '서울1호선')},
#     '솔밭공원': {'4.19민주묘지': (0.7, '우이신설선'), '북한산우이': (0.8, '우이신설선')},
#     '솔샘': {'북한산보국문': (1.2, '우이신설선'), '삼양사거리': (0.8, '우이신설선')},
#     '송내': {'중동': (1.2, '서울1호선')},
#     '송산': {'어룡': (0.63, '의정부경전철'), '탑석': (0.455, '의정부경전철')},
#     '송정': {'김포공항역': (1.2, '서울5호선'), '마곡': (1.1, '서울5호선')},
#     '송탄': {'서정리역': (2.2, '서울1호선'), '진위': (3.8, '서울1호선')},
#     '송파': {'가락시장역': (0.8, '서울8호선'), '석촌': (0.9, '서울8호선')},
#     '송파나루': {'석촌역': (0.8, '서울지하철9호선'), '한성백제': (0.8, '서울지하철9호선')},
#     '수내': {'서현': (1.1, '분당선'), '정자역': (1.6, '분당선')},
#     '수락산': {'도봉산역': (1.6, '서울7호선'), '마들': (1.4, '서울7호선')},
#     '수리산': {'대야미': (2.6, '서울4호선'), '산본': (1.1, '서울4호선')},
#     '수색': {'디지털미디어시티': (0.6, '경의중앙선(수도권전철)'), '분기': (1.7, '경의중앙선(수도권전철)')},
#     '수서역': {   '가락시장역': (1.4, '서울3호선'),
#                '대모산입구': (3.0, '분당선'),
#                '동탄': (32.6, nan),
#                '복정역': (3.2, '분당선'),
#                '일원': (1.8, '서울3호선')},
#     '수원시청': {'매교': (1.4, '분당선'), '매탄권선': (1.4, '분당선')},
#     '수원역': {'매교': (1.5, '분당선'), '세류': (2.9, '서울1호선'), '화서': (2.1, '서울1호선')},
#     '수유': {'미아': (1.4, '서울4호선'), '쌍문': (1.5, '서울4호선')},
#     '수지구청': {'동천': (2.1, '신분당선'), '성복': (1.7, '신분당선')},
#     '수진': {'모란역': (1.0, '서울8호선'), '신흥': (0.9, '서울8호선')},
#     '숙대입구': {'삼각지역': (1.2, '서울4호선'), '서울역': (1.0, '서울4호선')},
#     '숭실대입구': {'남성': (2.0, '서울7호선'), '상도': (0.9, '서울7호선')},
#     '시청,용인대': {'명지대': (1.034, '용인경전철'), '삼가': (1.045, '용인경전철')},
#     '시청역': {   '서울역': (1.1, '서울1호선'),
#                '을지로입구': (0.7, '서울2호선'),
#                '종각': (1.0, '서울1호선'),
#                '충정로역': (1.1, '서울2호선')},
#     '시흥기지': {'오이도역': (2.0, nan)},
#     '시흥능곡': {'달미': (2.4, '소사~원시'), '시흥시청': (1.3, '소사~원시')},
#     '시흥대야': {'소새울': (2.1, '소사~원시'), '신천': (1.4, '소사~원시')},
#     '시흥시청': {'시흥능곡': (1.3, '소사~원시'), '신현': (3.6, '소사~원시')},
#     '신갈': {'구성': (1.6, '분당선'), '기흥역': (1.4, '분당선')},
#     '신금호': {'청구역': (0.9, '서울5호선'), '행당': (0.8, '서울5호선')},
#     '신길역': {   '대방': (0.8, '서울1호선'),
#                '여의도역': (1.0, '서울5호선'),
#                '영등포시장': (1.1, '서울5호선'),
#                '영등포역': (1.0, '서울1호선')},
#     '신길온천': {'안산': (2.2, '서울4호선'), '정왕': (2.9, '서울4호선')},
#     '신내': {'갈매': (2.6, '경춘선(수도권전철)'), '망우역': (2.1, '경춘선(수도권전철)')},
#     '신내역': {'봉화산': (1.3, '서울6호선')},
#     '신논현': {'사평': (0.9, '서울9호선'), '언주': (0.8, '서울9호선')},
#     '신답': {'용답': (1.0, '서울2호선'), '용두': (0.9, '서울2호선')},
#     '신당역': {   '동대문역사문화공원': (0.9, '서울2호선'),
#                '동묘앞역': (0.6, '서울6호선'),
#                '상왕십리': (0.9, '서울2호선'),
#                '청구역': (0.7, '서울6호선')},
#     '신대방': {'구로디지털단지': (1.1, '서울2호선'), '신림': (1.8, '서울2호선')},
#     '신대방삼거리': {'보라매': (0.8, '서울7호선'), '장승배기': (1.2, '서울7호선')},
#     '신도림역': {   '구로역': (1.1, '서울1호선'),
#                 '대림역': (1.8, '서울2호선'),
#                 '도림천': (1.0, '서울2호선'),
#                 '문래': (1.2, '서울2호선'),
#                 '영등포역': (1.5, '서울1호선')},
#     '신둔도예촌': {'곤지암': (6.8, '경강선(수도권전철)'), '이천': (7.8, '경강선(수도권전철)')},
#     '신림': {'봉천': (1.1, '서울2호선'), '신대방': (1.8, '서울2호선')},
#     '신망리': {'연천': (3.6, '서울1호선')},
#     '신목동': {'선유도': (1.2, '서울9호선'), '염창': (0.9, '서울9호선')},
#     '신반포': {'고속터미널역': (0.8, '서울9호선'), '구반포': (0.7, '서울9호선')},
#     '신방화': {'공항시장': (0.8, '서울9호선'), '마곡나루': (0.9, '서울9호선')},
#     '신사': {'압구정': (1.5, '서울3호선'), '잠원': (0.9, '서울3호선')},
#     '신설동역': {   '동묘앞역': (0.7, '서울1호선'),
#                 '보문역': (1.0, '우이신설선'),
#                 '용두': (1.2, '서울2호선'),
#                 '제기동': (0.9, '서울1호선')},
#     '신용산': {'삼각지역': (0.7, '서울4호선'), '이촌역': (1.3, '서울4호선')},
#     '신원': {'국수': (2.9, '경의중앙선(수도권전철)'), '양수': (4.7, '경의중앙선(수도권전철)')},
#     '신이문': {'석계역': (1.4, '서울1호선'), '외대앞': (0.8, '서울1호선')},
#     '신정': {'까치산역': (1.3, '서울5호선'), '목동': (0.8, '서울5호선')},
#     '신정네거리': {'까치산역': (1.4, '서울2호선'), '양천구청': (1.9, '서울2호선')},
#     '신중동': {'부천시청': (1.1, '서울7호선'), '춘의': (1.0, '서울7호선')},
#     '신천': {'시흥대야': (1.4, '소사~원시'), '신현': (3.3, '소사~원시')},
#     '신촌': {   '가좌역': (2.7, '경의중앙선(수도권전철)'),
#               '서울역': (3.1, '경의중앙선(수도권전철)'),
#               '이대': (0.8, '서울2호선'),
#               '홍대입구역': (1.3, '서울2호선')},
#     '신탄리': {'대광리': (5.6, '서울1호선')},
#     '신풍': {'대림역': (1.4, '서울7호선'), '보라매': (0.9, '서울7호선')},
#     '신현': {'시흥시청': (3.6, '소사~원시'), '신천': (3.3, '소사~원시')},
#     '신흥': {'단대오거리': (0.8, '서울8호선'), '수진': (0.9, '서울8호선')},
#     '쌍문': {'수유': (1.5, '서울4호선'), '창동역': (1.3, '서울4호선')},
#     '아신': {'국수': (4.1, '경의중앙선(수도권전철)'), '오빈': (2.8, '경의중앙선(수도권전철)')},
#     '아차산': {'광나루': (1.5, '서울5호선'), '군자역': (1.0, '서울5호선')},
#     '아현': {'이대': (0.9, '서울2호선'), '충정로역': (0.8, '서울2호선')},
#     '안국': {'경복궁': (1.1, '서울3호선'), '종로3가역': (1.0, '서울3호선')},
#     '안산': {'신길온천': (2.2, '서울4호선'), '초지': (1.8, '서울4호선')},
#     '안암': {'고려대': (0.8, '서울6호선'), '보문역': (0.9, '서울6호선')},
#     '안양역': {'관악': (2.4, '서울1호선'), '명학': (2.2, '서울1호선')},
#     '암사': {'천호역': (1.3, '서울8호선')},
#     '압구정': {'신사': (1.5, '서울3호선'), '옥수역': (2.1, '서울3호선')},
#     '압구정로데오': {'강남구청역': (1.2, '분당선'), '서울숲': (1.9, '분당선')},
#     '애오개': {'공덕역': (1.1, '서울5호선'), '충정로역': (0.9, '서울5호선')},
#     '야당': {'운정': (1.5, '경의중앙선(수도권전철)'), '탄현': (2.1, '경의중앙선(수도권전철)')},
#     '야탑': {'모란역': (2.3, '분당선'), '이매역': (1.7, '분당선')},
#     '약수역': {   '금호': (0.8, '서울3호선'),
#                '동대입구': (0.7, '서울3호선'),
#                '버티고개': (0.7, '서울6호선'),
#                '청구역': (0.8, '서울6호선')},
#     '양수': {'신원': (4.7, '경의중앙선(수도권전철)'), '운길산': (1.9, '경의중앙선(수도권전철)')},
#     '양원': {'구리': (3.2, '경의중앙선(수도권전철)'), '망우역': (1.7, '경의중앙선(수도권전철)')},
#     '양재시민의숲': {'양재역': (1.6, '신분당선'), '청계산입구': (2.9, '신분당선')},
#     '양재역': {   '강남역': (1.5, '신분당선'),
#                '남부터미널': (1.8, '서울3호선'),
#                '매봉': (1.2, '서울3호선'),
#                '양재시민의숲': (1.6, '신분당선')},
#     '양정': {'덕소역': (2.3, '경의중앙선(수도권전철)'), '도농': (3.7, '경의중앙선(수도권전철)')},
#     '양주': {'녹양': (1.6, '서울1호선'), '덕계': (5.3, '서울1호선')},
#     '양천구청': {'도림천': (1.7, '서울2호선'), '신정네거리': (1.9, '서울2호선')},
#     '양천향교': {'가양': (1.3, '서울9호선'), '마곡나루': (1.4, '서울9호선')},
#     '양촌': {'구래': (1.4, '김포골드라인')},
#     '양평': {'영등포구청역': (0.8, '서울5호선'), '오목교': (1.1, '서울5호선')},
#     '양평역': {'오빈': (2.2, '경의중앙선(수도권전철)'), '원덕': (5.8, '경의중앙선(수도권전철)')},
#     '어룡': {'곤제': (0.904, '의정부경전철'), '송산': (0.63, '의정부경전철')},
#     '어린이대공원': {'건대입구역': (0.8, '서울7호선'), '군자역': (1.1, '서울7호선')},
#     '어정': {'동백': (1.185, '용인경전철'), '지석': (0.918, '용인경전철')},
#     '언주': {'선정릉역': (0.9, '서울9호선'), '신논현': (0.8, '서울9호선')},
#     '여의나루': {'마포': (1.8, '서울5호선'), '여의도역': (1.0, '서울5호선')},
#     '여의도역': {   '국회의사당': (0.9, '서울9호선'),
#                 '샛강': (0.8, '서울9호선'),
#                 '신길역': (1.0, '서울5호선'),
#                 '여의나루': (1.0, '서울5호선')},
#     '여주': {'세종대왕릉': (5.4, '경강선(수도권전철)')},
#     '역곡': {'소사': (1.5, '서울1호선'), '온수역': (1.3, '서울1호선')},
#     '역삼': {'강남역': (0.8, '서울2호선'), '선릉역': (1.2, '서울2호선')},
#     '역촌': {'불광역': (0.8, '서울6호선'), '응암': (1.1, '서울6호선')},
#     '연신내역': {   '구산': (0.9, '서울6호선'),
#                 '구파발': (2.0, '서울3호선'),
#                 '독바위': (1.4, '서울6호선'),
#                 '불광역': (1.3, '서울3호선')},
#     '연천': {'신망리': (3.6, '서울1호선'), '전곡': (8.6, '서울1호선')},
#     '염창': {'등촌': (0.9, '서울9호선'), '신목동': (0.9, '서울9호선')},
#     '영등포구청역': {   '당산역': (1.1, '서울2호선'),
#                   '문래': (0.9, '서울2호선'),
#                   '양평': (0.8, '서울5호선'),
#                   '영등포시장': (0.9, '서울5호선')},
#     '영등포시장': {'신길역': (1.1, '서울5호선'), '영등포구청역': (0.9, '서울5호선')},
#     '영등포역': {'신길역': (1.0, '서울1호선'), '신도림역': (1.5, '서울1호선')},
#     '영통': {'망포': (1.5, '분당선'), '청명': (1.1, '분당선')},
#     '오금역': {'개롱': (0.9, '서울5호선'), '경찰병원': (0.8, '서울3호선'), '방이': (0.9, '서울5호선')},
#     '오류동': {'개봉': (1.3, '서울1호선'), '온수역': (1.9, '서울1호선')},
#     '오리': {'미금역': (1.1, '분당선'), '분당기지': (2.3, nan), '죽전': (1.8, '분당선')},
#     '오목교': {'목동': (0.9, '서울5호선'), '양평': (1.1, '서울5호선')},
#     '오봉': {'의왕': (3.0, '서울1호선')},
#     '오빈': {'아신': (2.8, '경의중앙선(수도권전철)'), '양평역': (2.2, '경의중앙선(수도권전철)')},
#     '오산대': {'세마': (2.7, '서울1호선'), '오산역': (2.7, '서울1호선')},
#     '오산역': {'오산대': (2.7, '서울1호선'), '진위': (4.0, '서울1호선')},
#     '오이도역': {'달월': (2.1, '수인선'), '시흥기지': (2.0, nan), '정왕': (1.4, '서울4호선')},
#     '옥수역': {   '금호': (0.8, '서울3호선'),
#                '압구정': (2.1, '서울3호선'),
#                '응봉': (1.8, '경의중앙선(수도권전철)'),
#                '한남': (1.6, '경의중앙선(수도권전철)')},
#     '온수역': {   '까치울': (2.2, '서울7호선'),
#                '역곡': (1.3, '서울1호선'),
#                '오류동': (1.9, '서울1호선'),
#                '천왕': (1.5, '서울7호선')},
#     '올림픽공원': {'둔촌동': (1.4, '서울5호선'), '방이': (0.9, '서울5호선')},
#     '올림픽공원역': {'둔촌오륜': (1.0, '서울지하철9호선'), '한성백제': (1.4, '서울지하철9호선')},
#     '왕십리역': {   '마장': (0.7, '서울5호선'),
#                 '상왕십리': (0.8, '서울2호선'),
#                 '서울숲': (2.2, '분당선'),
#                 '응봉': (1.4, '경의중앙선(수도권전철)'),
#                 '청량리역': (2.4, '분당선'),
#                 '한양대': (1.0, '서울2호선'),
#                 '행당': (0.9, '서울5호선')},
#     '외대앞': {'신이문': (0.8, '서울1호선'), '회기역': (0.8, '서울1호선')},
#     '용답': {'성수역': (2.3, '서울2호선'), '신답': (1.0, '서울2호선')},
#     '용두': {'신답': (0.9, '서울2호선'), '신설동역': (1.2, '서울2호선')},
#     '용마산': {'사가정': (0.8, '서울7호선'), '중곡': (0.9, '서울7호선')},
#     '용문역': {'원덕': (4.8, '경의중앙선(수도권전철)'), '지평역': (3.6, '경의중앙선(수도권전철)')},
#     '용산역': {   '남영': (1.5, '서울1호선'),
#                '분기점': (0.8, '경의중앙선(수도권전철)'),
#                '효창공원앞': (1.5, '경의중앙선(수도권전철)')},
#     '우장산': {'발산': (1.1, '서울5호선'), '화곡': (1.0, '서울5호선')},
#     '운길산': {'양수': (1.9, '경의중앙선(수도권전철)'), '팔당': (6.4, '경의중앙선(수도권전철)')},
#     '운동장,송담대': {'고진': (0.935, '용인경전철'), '김량장': (0.945, '용인경전철')},
#     '운양': {'걸포북변': (3.47, '김포골드라인'), '장기': (1.7, '김포골드라인')},
#     '운정': {'금릉': (3.1, '경의중앙선(수도권전철)'), '야당': (1.5, '경의중앙선(수도권전철)')},
#     '운천': {'문산': (3.7, '경의중앙선(수도권전철)'), '임진강': (2.3, '경의중앙선(수도권전철)')},
#     '원곡': {'원시': (1.5, '소사~원시'), '초지역': (1.4, '소사~원시')},
#     '원당': {'원흥': (2.9, '서울3호선'), '화정': (2.6, '서울3호선')},
#     '원덕': {'양평역': (5.8, '경의중앙선(수도권전철)'), '용문역': (4.8, '경의중앙선(수도권전철)')},
#     '원시': {'원곡': (1.5, '소사~원시')},
#     '원흥': {'삼송': (2.1, '서울3호선'), '원당': (2.9, '서울3호선')},
#     '월계': {'광운대역': (1.1, '서울1호선'), '녹천': (1.4, '서울1호선')},
#     '월곡': {'고려대': (1.4, '서울6호선'), '상월곡': (0.8, '서울6호선')},
#     '월곶': {'달월': (1.5, '수인선')},
#     '월드컵경기장': {'디지털미디어시티': (0.8, '서울6호선'), '마포구청': (0.8, '서울6호선')},
#     '월롱': {'금촌': (4.1, '경의중앙선(수도권전철)'), '파주': (2.2, '경의중앙선(수도권전철)')},
#     '을지로3가역': {   '을지로4가역': (0.6, '서울2호선'),
#                   '을지로입구': (0.8, '서울2호선'),
#                   '종로3가역': (0.6, '서울3호선'),
#                   '충무로역': (0.7, '서울3호선')},
#     '을지로4가역': {   '동대문역사문화공원': (0.9, '서울5호선'),
#                   '을지로3가역': (0.6, '서울2호선'),
#                   '종로3가역': (1.0, '서울5호선')},
#     '을지로입구': {'시청역': (0.7, '서울2호선'), '을지로3가역': (0.8, '서울2호선')},
#     '응봉': {'옥수역': (1.8, '경의중앙선(수도권전철)'), '왕십리역': (1.4, '경의중앙선(수도권전철)')},
#     '응암': {'구산': (1.5, '서울6호선'), '새절': (0.9, '서울6호선'), '역촌': (1.1, '서울6호선')},
#     '의왕': {'당정': (2.6, '서울1호선'), '성균관대': (2.9, '서울1호선'), '오봉': (3.0, '서울1호선')},
#     '의정부': {'가능': (1.2, '서울1호선'), '회룡역': (1.6, '서울1호선')},
#     '의정부시청': {'경전철의정부': (0.92, '의정부경전철'), '흥선': (0.627, '의정부경전철')},
#     '의정부중앙': {'동오': (0.703, '의정부경전철'), '흥선': (1.107, '의정부경전철')},
#     '이대': {'신촌': (0.8, '서울2호선'), '아현': (0.9, '서울2호선')},
#     '이매역': {   '삼동': (6.9, '경강선(수도권전철)'),
#                '서현': (1.4, '분당선'),
#                '야탑': (1.7, '분당선'),
#                '판교역': (1.5, '경강선(수도권전철)')},
#     '이천': {'부발': (4.5, '경강선(수도권전철)'), '신둔도예촌': (7.8, '경강선(수도권전철)')},
#     '이촌역': {   '동작역': (2.7, '서울4호선'),
#                '분기점': (1.1, '경의중앙선(수도권전철)'),
#                '서빙고': (1.7, '경의중앙선(수도권전철)'),
#                '신용산': (1.3, '서울4호선')},
#     '이태원': {'녹사평': (0.8, '서울6호선'), '한강진': (1.0, '서울6호선')},
#     '인덕원': {'정부과천청사': (3.0, '서울4호선'), '평촌': (1.6, '서울4호선')},
#     '일산': {'탄현': (1.7, '경의중앙선(수도권전철)'), '풍산': (1.9, '경의중앙선(수도권전철)')},
#     '일원': {'대청': (1.2, '서울3호선'), '수서역': (1.8, '서울3호선')},
#     '임진강': {'도라산': (3.7, '경의중앙선(수도권전철)'), '운천': (2.3, '경의중앙선(수도권전철)')},
#     '잠실나루역': {'강변': (1.8, '서울2호선'), '잠실역': (1.0, '서울2호선')},
#     '잠실새내': {'잠실역': (1.2, '서울2호선'), '종합운동장역': (1.2, '서울2호선')},
#     '잠실역': {   '몽촌토성': (0.8, '서울8호선'),
#                '석촌': (1.2, '서울8호선'),
#                '잠실나루역': (1.0, '서울2호선'),
#                '잠실새내': (1.2, '서울2호선')},
#     '잠원': {'고속터미널역': (1.2, '서울3호선'), '신사': (0.9, '서울3호선')},
#     '장기': {'마산역': (2.6, '김포골드라인'), '운양': (1.7, '김포골드라인')},
#     '장승배기': {'상도': (0.9, '서울7호선'), '신대방삼거리': (1.2, '서울7호선')},
#     '장암': {'도봉산역': (1.4, '서울7호선')},
#     '장지': {'문정': (0.9, '서울8호선'), '복정역': (0.9, '서울8호선')},
#     '장한평': {'군자역': (1.5, '서울5호선'), '답십리': (1.2, '서울5호선')},
#     '전곡': {'연천': (8.6, '서울1호선'), '한탄강': (2.5, '서울1호선')},
#     '전대,에버랜드': {'둔전': (2.626, '용인경전철')},
#     '정릉': {'북한산보국문': (1.2, '우이신설선'), '성신여대입구': (1.2, '우이신설선')},
#     '정발산': {'마두': (0.9, '서울3호선'), '주엽': (1.6, '서울3호선')},
#     '정부과천청사': {'과천': (1.0, '서울4호선'), '인덕원': (3.0, '서울4호선')},
#     '정왕': {'신길온천': (2.9, '서울4호선'), '오이도역': (1.4, '서울4호선')},
#     '정자역': {'미금역': (1.9, '신분당선'), '수내': (1.6, '분당선'), '판교역': (3.1, '신분당선')},
#     '제기동': {'신설동역': (0.9, '서울1호선'), '청량리역': (1.0, '서울1호선')},
#     '종각': {'시청역': (1.0, '서울1호선'), '종로3가역': (0.8, '서울1호선')},
#     '종로3가역': {   '광화문': (1.2, '서울5호선'),
#                  '안국': (1.0, '서울3호선'),
#                  '을지로3가역': (0.6, '서울3호선'),
#                  '을지로4가역': (1.0, '서울5호선'),
#                  '종각': (0.8, '서울1호선'),
#                  '종로5가': (0.9, '서울1호선')},
#     '종로5가': {'동대문': (0.8, '서울1호선'), '종로3가역': (0.9, '서울1호선')},
#     '종합운동장역': {   '봉은사': (1.4, '서울9호선'),
#                   '삼성': (1.0, '서울2호선'),
#                   '삼전': (1.4, '서울지하철9호선'),
#                   '잠실새내': (1.2, '서울2호선')},
#     '주엽': {'대화': (1.4, '서울3호선'), '정발산': (1.6, '서울3호선')},
#     '죽전': {'보정': (1.3, '분당선'), '오리': (1.8, '분당선')},
#     '중계': {'노원역': (1.1, '서울7호선'), '하계': (1.0, '서울7호선')},
#     '중곡': {'군자역': (1.1, '서울7호선'), '용마산': (0.9, '서울7호선')},
#     '중동': {'부천': (1.7, '서울1호선'), '송내': (1.2, '서울1호선')},
#     '중랑역': {'상봉역': (0.8, '경춘선(수도권전철)'), '회기역': (1.8, '경춘선(수도권전철)')},
#     '중앙': {'고잔': (1.4, '서울4호선'), '한대앞': (1.6, '서울4호선')},
#     '중앙보훈병원': {'둔촌오륜': (1.7, '서울지하철9호선')},
#     '중화': {'먹골': (0.9, '서울7호선'), '상봉역': (1.0, '서울7호선')},
#     '증미': {'가양': (0.7, '서울9호선'), '등촌': (1.0, '서울9호선')},
#     '증산': {'디지털미디어시티': (1.1, '서울6호선'), '새절': (0.9, '서울6호선')},
#     '지석': {'강남대': (1.062, '용인경전철'), '어정': (0.918, '용인경전철')},
#     '지제역': {   '동탄': (21.0, nan),
#                '분기': (7.5, nan),
#                '서정리역': (4.8, '서울1호선'),
#                '평택역': (3.7, '서울1호선')},
#     '지축': {'구파발': (1.5, '서울3호선'), '삼송': (1.7, '서울3호선')},
#     '지평역': {'석불': (2.9, '경의중앙선(수도권전철)'), '용문역': (3.6, '경의중앙선(수도권전철)')},
#     '지행': {'덕정': (5.6, '서울1호선'), '동두천중앙': (1.0, '서울1호선')},
#     '진위': {'송탄': (3.8, '서울1호선'), '오산역': (4.0, '서울1호선')},
#     '창동역': {   '노원역': (1.4, '서울4호선'),
#                '녹천': (1.0, '서울1호선'),
#                '방학': (1.7, '서울1호선'),
#                '쌍문': (1.3, '서울4호선')},
#     '창신': {'동묘앞역': (0.9, '서울6호선'), '보문역': (0.8, '서울6호선')},
#     '천마산': {'마석역': (2.2, '경춘선(수도권전철)'), '평내호평역': (4.2, '경춘선(수도권전철)')},
#     '천왕': {'광명사거리': (1.7, '서울7호선'), '온수역': (1.5, '서울7호선')},
#     '천호역': {   '강동구청': (0.9, '서울8호선'),
#                '강동역': (0.8, '서울5호선'),
#                '광나루': (2.0, '서울5호선'),
#                '암사': (1.3, '서울8호선')},
#     '철산': {'가산디지털단지': (1.4, '서울7호선'), '광명사거리': (1.3, '서울7호선')},
#     '청계산입구': {'양재시민의숲': (2.9, '신분당선'), '판교역': (8.2, '신분당선')},
#     '청구역': {   '동대문역사문화공원': (0.9, '서울5호선'),
#                '신금호': (0.9, '서울5호선'),
#                '신당역': (0.7, '서울6호선'),
#                '약수역': (0.8, '서울6호선')},
#     '청담': {'강남구청역': (1.1, '서울7호선'), '뚝섬유원지': (2.0, '서울7호선')},
#     '청량리역': {   '왕십리역': (2.4, '분당선'),
#                 '제기동': (1.0, '서울1호선'),
#                 '회기역': (1.4, '경춘선(수도권전철)')},
#     '청명': {'상갈': (2.8, '분당선'), '영통': (1.1, '분당선')},
#     '청평역': {'대성리': (7.5, '경춘선(수도권전철)'), '상천': (4.8, '경춘선(수도권전철)')},
#     '초당': {'동백': (1.097, '용인경전철'), '삼가': (2.591, '용인경전철')},
#     '초성리': {'소요산역': (4.1, '서울1호선'), '한탄강': (3.0, '서울1호선')},
#     '초월': {'경기광주': (5.0, '경강선(수도권전철)'), '곤지암': (4.9, '경강선(수도권전철)')},
#     '초지': {'고잔': (1.5, '서울4호선'), '안산': (1.8, '서울4호선')},
#     '초지역': {'선부': (1.7, '소사~원시'), '원곡': (1.4, '소사~원시')},
#     '총신대입구역': {   '남성': (1.0, '서울7호선'),
#                   '내방': (1.0, '서울7호선'),
#                   '동작역': (1.8, '서울4호선'),
#                   '사당역': (1.1, '서울4호선')},
#     '춘의': {'부천종합운동장': (0.9, '서울7호선'), '신중동': (1.0, '서울7호선')},
#     '충무로역': {   '동대문역사문화공원': (1.3, '서울4호선'),
#                 '동대입구': (0.9, '서울3호선'),
#                 '명동': (0.7, '서울4호선'),
#                 '을지로3가역': (0.7, '서울3호선')},
#     '충정로역': {   '서대문': (0.7, '서울5호선'),
#                 '시청역': (1.1, '서울2호선'),
#                 '아현': (0.8, '서울2호선'),
#                 '애오개': (0.9, '서울5호선')},
#     '탄현': {'야당': (2.1, '경의중앙선(수도권전철)'), '일산': (1.7, '경의중앙선(수도권전철)')},
#     '탑석': {'송산': (0.455, '의정부경전철')},
#     '태릉입구역': {   '공릉': (0.8, '서울7호선'),
#                  '먹골': (0.9, '서울7호선'),
#                  '석계역': (0.8, '서울6호선'),
#                  '화랑대': (0.9, '서울6호선')},
#     '태평': {'가천대': (1.0, '분당선'), '모란역': (0.9, '분당선')},
#     '퇴계원역': {'별내': (1.6, '경춘선(수도권전철)'), '사릉역': (3.3, '경춘선(수도권전철)')},
#     '파주': {'문산': (4.4, '경의중앙선(수도권전철)'), '월롱': (2.2, '경의중앙선(수도권전철)')},
#     '판교역': {   '이매역': (1.5, '경강선(수도권전철)'),
#                '정자역': (3.1, '신분당선'),
#                '청계산입구': (8.2, '신분당선')},
#     '팔당': {'도심': (4.2, '경의중앙선(수도권전철)'), '운길산': (6.4, '경의중앙선(수도권전철)')},
#     '평내기지': {'평내호평역': (2.5, nan)},
#     '평내호평역': {   '금곡': (4.0, '경춘선(수도권전철)'),
#                  '천마산': (4.2, '경춘선(수도권전철)'),
#                  '평내기지': (2.5, nan)},
#     '평촌': {'범계': (1.3, '서울4호선'), '인덕원': (1.6, '서울4호선')},
#     '평택역': {'지제역': (3.7, '서울1호선'), '평택역': (9.4, '서울1호선')},
#     '풍무': {'고촌역': (3.6, '김포골드라인'), '사우': (1.6, '김포골드라인')},
#     '풍산': {'백마': (1.7, '경의중앙선(수도권전철)'), '일산': (1.9, '경의중앙선(수도권전철)')},
#     '하계': {'공릉': (1.3, '서울7호선'), '중계': (1.0, '서울7호선')},
#     '학동': {'강남구청역': (0.9, '서울7호선'), '논현': (1.0, '서울7호선')},
#     '학여울': {'대청': (0.9, '서울3호선'), '대치': (0.8, '서울3호선')},
#     '한강진': {'버티고개': (1.0, '서울6호선'), '이태원': (1.0, '서울6호선')},
#     '한남': {'서빙고': (1.9, '경의중앙선(수도권전철)'), '옥수역': (1.6, '경의중앙선(수도권전철)')},
#     '한대앞': {'상록수': (1.5, '서울4호선'), '중앙': (1.6, '서울4호선')},
#     '한성대입구': {'성신여대입구': (1.0, '서울4호선'), '혜화': (0.9, '서울4호선')},
#     '한성백제': {'송파나루': (0.8, '서울지하철9호선'), '올림픽공원역': (1.4, '서울지하철9호선')},
#     '한양대': {'뚝섬': (1.1, '서울2호선'), '왕십리역': (1.0, '서울2호선')},
#     '한탄강': {'전곡': (2.5, '서울1호선'), '초성리': (3.0, '서울1호선')},
#     '한티': {'도곡역': (0.7, '분당선'), '선릉역': (1.0, '분당선')},
#     '합정역': {   '당산역': (2.0, '서울2호선'),
#                '망원': (0.8, '서울6호선'),
#                '상수': (0.8, '서울6호선'),
#                '홍대입구역': (1.1, '서울2호선')},
#     '행당': {'신금호': (0.8, '서울5호선'), '왕십리역': (0.9, '서울5호선')},
#     '행신역': {'강매': (0.9, '경의중앙선(수도권전철)'), '능곡': (1.5, '경의중앙선(수도권전철)')},
#     '혜화': {'동대문역': (1.5, '서울4호선'), '한성대입구': (0.9, '서울4호선')},
#     '홍대입구역': {   '가좌역': (1.7, '경의중앙선(수도권전철)'),
#                  '공덕역': (2.8, '공항철도'),
#                  '디지털미디어시티': (3.4, '공항철도'),
#                  '서강대': (0.9, '경의중앙선(수도권전철)'),
#                  '신촌': (1.3, '서울2호선'),
#                  '합정역': (1.1, '서울2호선')},
#     '홍제': {'녹번': (1.6, '서울3호선'), '무악재': (0.9, '서울3호선')},
#     '화계': {'가오리': (0.8, '우이신설선'), '삼양': (0.8, '우이신설선')},
#     '화곡': {'까치산역': (1.2, '서울5호선'), '우장산': (1.0, '서울5호선')},
#     '화랑대': {'봉화산': (0.7, '서울6호선'), '태릉입구역': (0.9, '서울6호선')},
#     '화서': {'성균관대': (2.6, '서울1호선'), '수원역': (2.1, '서울1호선')},
#     '화전': {'강매': (2.5, '경의중앙선(수도권전철)'), '분기': (1.7, '경의중앙선(수도권전철)')},
#     '화정': {'대곡역': (2.1, '서울3호선'), '원당': (2.6, '서울3호선')},
#     '회기역': {   '외대앞': (0.8, '서울1호선'),
#                '중랑역': (1.8, '경춘선(수도권전철)'),
#                '청량리역': (1.4, '경춘선(수도권전철)')},
#     '회룡역': {   '망월사': (1.4, '서울1호선'),
#                '발곡': (0.833, '의정부경전철'),
#                '범골': (0.615, '의정부경전철'),
#                '의정부': (1.6, '서울1호선')},
#     '회현': {'명동': (0.7, '서울4호선'), '서울역': (0.9, '서울4호선')},
#     '효자': {'경기도청북부청사': (0.63, '의정부경전철'), '곤제': (0.772, '의정부경전철')},
#     '효창공원앞': {   '공덕역': (1.0, '경의중앙선(수도권전철)'),
#                  '삼각지역': (1.2, '서울6호선'),
#                  '용산역': (1.5, '경의중앙선(수도권전철)')},
#     '흑석': {'노들': (1.1, '서울9호선'), '동작역': (1.4, '서울9호선')},
#     '흥선': {'의정부시청': (0.627, '의정부경전철'), '의정부중앙': (1.107, '의정부경전철')}}

# %%
# 필요한 데이터만 추출
station_data = df[['출발역', '호선']]

# 역과 호선을 기준으로 중복 제거
unique_station_lines = station_data.drop_duplicates()

# 각 역이 몇 개의 호선에 속하는지 세기
station_line_count = unique_station_lines.groupby('출발역').count()

# 환승역 찾기: 2개 이상의 호선에 속하는 역
transfer_stations = station_line_count[station_line_count['호선'] > 1].index.tolist()

transfer_stations, len(transfer_stations)
# Out:
# (['가산디지털단지',
#   '고속터미널역',
#   '공덕역',
#   '광운대역',
#   '금정역',
#   '김포공항역',
#   '까치산역',
#   '노량진역',
#   '노원역',
#   '당산역',
#   '대곡역',
#   '대림역',
#   '도봉산역',
#   '동묘앞역',
#   '동작역',
#   '디지털미디어시티',
#   '망우역',
#   '복정역',
#   '분기',
#   '분기점',
#   '불광역',
#   '삼각지역',
#   '상봉역',
#   '서울역',
#   '석계역',
#   '선릉역',
#   '선정릉역',
#   '성신여대입구',
#   '수서역',
#   '시청역',
#   '신도림역',
#   '신설동역',
#   '신촌',
#   '양재역',
#   '여의도역',
#   '영등포구청역',
#   '오금역',
#   '오이도역',
#   '왕십리역',
#   '을지로4가역',
#   '이매역',
#   '이촌역',
#   '잠실역',
#   '정자역',
#   '종합운동장역',
#   '천호역',
#   '청구역',
#   '청량리역',
#   '충무로역',
#   '합정역',
#   '홍대입구역',
#   '회기역',
#   '회룡역',
#   '효창공원앞'],
#  54)

# %%
nodes = {source for source in g}
nodes.update({dest for destinations in g.values() for dest in destinations})
print(nodes)
# Out:
# {'대성리', '구성', '달월', '지석', '범계', '주엽', '평내호평역', '상일동', '동오', '동백', '도농', '응봉', '마곡', '사가정', '모란역', '태평', '양재시민의숲', '청구역', '약수역', '광나루', '강매', '한대앞', '용마산', '광운대역', '안암', '도곡역', '미금역', '장지', '신정네거리', '영통', '역삼', '안산', '운양', '정부과천청사', '개화산', '청량리역', '올림픽공원역', '춘의', '홍제', '당산역', '하계', '중앙보훈병원', '서울대입구', '상계', '마들', '창동역', '양평', '김포공항역', '백마', '망원', '잠실새내', '뚝섬유원지', '양원', '구룡', '오산역', '신방화', '지평역', '신금호', '먹골', '선바위', '정자역', '학동', '남부터미널', '죽전', '노량진역', '거여', '중앙', '종로3가역', '매봉', '송정', '기흥역', '수색', '오목교', '성수역', '어룡', '진위', '길음', '총신대입구역', '군포', '야탑', '수지구청', '당정', '의왕', '초지', '영등포역', '한남', '신정', '고진', '화정', '면목', '역곡', '구산', '새말', '시흥능곡', '논현', '산성', '평택역', '보문역', '장암', '원곡', '삼동', '수유', '지제역', '금천구청역', '중곡', '상도', '방학', '덕소역', '서빙고', '아신', '고려대', '사릉역', '동두천중앙', '명지대', '능곡', '성신여대입구', '석계역', '굴봉산', '가산디지털단지', '월곶', '초성리', '이천', '언주', '중동', '구파발', '신대방', '도림천', '신길온천', '동작역', '분기', '천왕', '천호역', '신답', '양정', '청명', '시흥기지', '신내역', '녹사평', '아현', '판교역', '화서', '충정로역', '반포', '길동', '청평역', '아차산', '양평역', '의정부시청', '신원', '고촌역', '버티고개', '양천구청', '봉은사', '삼성중앙', '신당역', '한티', '명동', '구리', '화곡', '화계', '상록수', '가양', '경기도청북부청사', '광화문', '성균관대', '곤지암', '송파', '풍무', '도심', '수원역', '동대문역사문화공원', '불광역', '대치', '신길역', '청담', '압구정', '강동역', '대곡역', '여의도역', '임진강', '디지털미디어시티', '숭실대입구', '대야미', '망월사', '대청', '쌍문', '신촌', '영등포구청역', '서정리역', '어정', '잠원', '양주', '을지로3가역', '화랑대', '고속터미널역', '신내', '매교', '둔촌오륜', '석촌', '신논현', '명일', '충무로역', '솔밭공원', '백석', '대모산입구', '구로디지털단지', '마천', '보정', '개화', '왕십리역', '상수', '산본', '대공원', '원당', '원시', '석촌역', '동대입구', '응암', '부천시청', '양수', '복정역', '한양대', '수리산', '용답', '송탄', '탄현', '개포동', '강남역', '방화', '시흥대야', '태릉입구역', '금곡', '월롱', '원흥', '광교', '곤제', '수락산', '신갈', '상동', '제기동', '북한산우이', '샛강', '
# %%
n_nodes = len(nodes)
n_edges = sum((len(destinations) for destinations in g.values()))
print('n_nodes = {}, n_edges = {}'.format(n_nodes, n_edges))
# n_nodes = 8, n_edges = 26
# Out:
# n_nodes = 542, n_edges = 1239

# %%
# max_cost =  max(w for nw in g.values() for w in nw.values())
# init_cost = n_nodes * (max_cost + 1)
# print('max_cost = {}, init_cost = {}'.format(max_cost, init_cost))
# # max_cost = 34.0 init_cost = 280.0

# %%
def initialize(start):
    cost = {node:(0 if node == start else 'inf') for node in nodes}
    return cost

cost = initialize('교대역')

# %%
def update(cost):
    changed = False
    for from_, to_weight in g.items():
        for to_, weight in to_weight.items():
            if cost[to_] > cost[from_] + weight:
                before = cost[to_]
                after = cost[from_] + weight
                cost[to_] = after
                changed = True
                print('{} -> {} : {} -> {}'.format(from_, to_, before, after))
    return cost, changed

# %%
def ford(start, destination, graph):
    # 모든 노드의 초기 비용을 무한으로 설정하고, 시작 노드의 비용을 0으로 초기화
    cost = {node: float('inf') for node in graph}
    cost[start] = 0
    previous_line = {node: None for node in graph}  # 이전 호선을 추적
    path = {node: None for node in graph}  # 최단 경로 추적

    # 그래프의 노드 수만큼 반복
    for _ in range(len(graph) - 1):
        updated = False
        for u in graph:
            for v, (dist, line) in graph[u].items():
                # 현재 노드 u에서 v로 가는데 필요한 호선 변경 비용을 계산
                transfer_penalty = 2.0 if previous_line[u] and previous_line[u] != line else 0
                new_cost = cost[u] + dist + transfer_penalty
                # 새로운 비용이 기존 비용보다 작으면 업데이트
                if cost[v] > new_cost:
                    cost[v] = new_cost
                    previous_line[v] = line
                    path[v] = u
                    updated = True
        if not updated:  # 더 이상 업데이트가 없으면 종료
            break

    # 목적지에서 시작하여 역으로 최단 경로를 추적
    shortest_path = []
    current_node = destination
    while current_node is not None:
        shortest_path.append(current_node)
        current_node = path[current_node]
    shortest_path.reverse()

    return shortest_path, cost[destination]

start = '교대역'
destination = '수원역'
print(ford(start, destination, g))
x = ford(start, destination, g)[1]
# Out:
# (['교대역', '서초', '방배', '사당역', '남태령', '선바위', '경마공원', '대공원', '과천', '정부과천청사', '인덕원', '평촌', '범계', '금정역', '군포', '당정', '의왕', '성균관대', '화서', '수원역'], 38.00000000000001)

# %%
df1 = pd.read_csv('/content/drive/MyDrive/KHU-TON/버스_노선별평균거리.csv', encoding='cp949')
df2 = pd.read_csv('/content/drive/MyDrive/KHU-TON/서울시버스노선별정류소정보(20240507).csv', encoding = 'cp949')

# %%
#df1, df2 merge

result_df = pd.merge(df1, df2, on='노선명', how='inner')  # inner join을 사용하여 두 데이터프레임 모두에 존재하는 '노선명' 데이터만 합치기
result_df
# Out:
#        OID_  Shape_Length           노선명  버스정류장 수  평균구간길이(Km)   ROUTE_ID  순번  \
# 0         2      1.201725           01A       78    1.540673  100100001   1
# 1         2      1.201725           01A       78    1.540673  104000007   1
# 2         2      1.201725           01A       78    1.540673  104000007   2
# 3         2      1.201725           01A       78    1.540673  100100001   2
# 4         2      1.201725           01A       78    1.540673  100100001   3
# ...     ...           ...           ...      ...         ...        ...  ..
# 46551   782      0.021941  청와대A01(자율주행)        6    0.365682  100000020   2
# 46552   782      0.021941  청와대A01(자율주행)        6    0.365682  100000020   3
# 46553   782      0.021941  청와대A01(자율주행)        6    0.365682  100000020   4
# 46554   782      0.021941  청와대A01(자율주행)        6    0.365682  100000020   5
# 46555   782      0.021941  청와대A01(자율주행)        6    0.365682  100000020   6
#
#          NODE_ID  ARS_ID             정류소명         X좌표        Y좌표
# 0      101000331    2291      남산예장버스환승주차장  126.989289  37.559740
# 1      101000006    2006        서울역버스환승센터  126.972855  37.555479
# 2      101000018    2110      경찰청.동북아역사재단  126.969127  37.563049
# 3      101000053    2152  퇴계로3가.한옥마을.한국의집  126.992410  37.560902
# 4      101000054    2153   충무로역2번출구.대한극장앞  126.994728  37.561238
# ...          ...     ...              ...         ...        ...
# 46551  100000415    1119          국립고궁박물관  126.973979  37.578928
# 46552  100000416    1601              청와대  126.973762  37.582971
# 46553  100000417    1602              춘추문  126.979657  37.583126
# 46554  100000418    1603      경복궁.국립민속박물관  126.979590  37.579407
# 46555  100000420    1604        효자로입구(가상)  126.974433  37.576265
#
# [46556 rows x 12 columns]

# %%
grouped = result_df.groupby('노선명')

# 결과를 저장할 빈 데이터프레임
processed_dfs = []

# 각 그룹에 대해 처리
for name, group in grouped:
    # 현재 그룹의 '정류소명'을 '출발정류소'로 설정
    group['출발정류소'] = group['정류소명']
    # 현재 그룹의 '정류소명'을 다음 행의 '도착정류소'로 설정
    group['도착정류소'] = group['정류소명'].shift(-1)
    # 마지막 행을 첫 번째 행의 '정류소명'으로 설정
    group.iloc[-1, group.columns.get_loc('도착정류소')] = group.iloc[0]['정류소명']
    # 결과 데이터프레임에 추가
    processed_dfs.append(group)

# 모든 처리된 데이터를 하나의 데이터프레임으로 결합
final_df = pd.concat(processed_dfs)

# 결과 저장
final_df.to_csv("processed_bus_routes.csv", index=False, encoding='cp949')

# %%
g = {}

# 데이터를 반복하면서 그래프 생성
for _, row in final_df.iterrows():
    station1 = row['출발정류소']
    station2 = row['도착정류소']
    distance = row['평균구간길이(Km)']  # 거리 데이터 컬럼명은 확인 필요
    line = row['노선명']  # 버스 노선 정보 컬럼명

    if station1 not in g:
        g[station1] = {}
    if station2 not in g:
        g[station2] = {}

    # 역간 거리와 노선 정보를 튜플로 저장
    g[station1][station2] = (distance, line)
    g[station2][station1] = (distance, line)  # 양방향 연결 가정

# 결과 출력
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(g)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#                 '광화문.금호아시아나본관앞': (0.5645127097409511, 'N26A'),
#                 '서울신문사': (0.4707337581518207, '501'),
#                 '세종문화회관': (0.3691727954768063, '7212'),
#                 '조계사.종로경찰서': (0.4811146903550055, '606'),
#                 '종각역YMCA': (2.050515241951297, '6002'),
#                 '종로2가': (0.54180908694339, '심야A21')},
#     '종로2가': {   '롯데백화점': (0.4820346505876999, '143'),
#                 '우리은행종로지점': (0.4457140404341607, 'N62B'),
#                 '을지로입구.시청입구': (0.519857843824451, '8101'),
#                 '을지로입구역.광교': (0.4457140404341607, 'N62B'),
#                 '종로1가': (0.54180908694339, '심야A21'),
#                 '종로2가.삼일교': (0.6072931544966456, 'N37'),
#                 '종로2가사거리': (0.6072931544966456, 'N37'),
#                 '종로3가': (0.4457140404341607, 'N62B'),
#                 '종로3가.탑골공원': (0.54180908694339, '심야A21')},
#     '종로2가.삼일교': {   '남대문세무서': (0.6072931544966456, 'N37'),
#                     '남인사마당': (1.5406725646804948, '01A'),
#                     '롯데백화점': (1.5406725646804948, '01A'),
#                     '우리은행종로지점': (0.4731573900218164, '701'),
#                     '을지로2가.기업은행본점.서울노동청': (0.4731573900218164, '701'),
#                     '종로2가': (0.6072931544966456, 'N37')},
#     '종로2가사거리': {   '국가인권위.안중근활동터': (0.6072931544966456, 'N37'),
#                    '종로2가': (0.6072931544966456, 'N37')},
#     '종로3가': {   '동대문종합시장': (2.050515241951297, '6002'),
#                 '종각역YMCA': (2.050515241951297, '6002'),
#                 '종로2가': (0.4457140404341607, 'N62B'),
#                 '종로4가': (2.050515241951297, '6002'),
#                 '종로4가.종묘': (0.4457140404341607, 'N62B')},
#     '종로3가.1.3.5호선': {   '종로1.2.3.4가동주민센터': (0.2571696958506562, '종로12'),
#                         '종로4가.종묘공원': (0.2571696958506562, '종로12')},
#     '종로3가.탑골공원': {   '국가인권위.안중근활동터': (0.611096269567346, '140'),
#                      '원남동': (0.650519816192596, '601'),
#                      '종로2가': (0.54180908694339, '심야A21'),
#                      '종로4가.종묘': (0.54180908694339, '심야A21'),
#                      '혜화경찰서': (0.385355956457967, '273')},
#     '종로4가': {   '동대문종합시장종로6가': (2.050515241951297, '6002'),
#                 '종로3가': (2.050515241951297, '6002')},
#     '종로4가.종묘': {   '원남동': (0.4894193178547822, 'N31'),
#                    '종로3가': (0.4457140404341607, 'N62B'),
#                    '종로3가.탑골공원': (0.54180908694339, '심야A21'),
#                    '종로5가': (0.4457140404341607, 'N62B'),
#                    '종로5가.광장시장': (0.54180908694339, '심야A21')},
#     '종로4가.종묘공원': {   '종로3가.1.3.5호선': (0.2571696958506562, '종로12'),
#                      '종로5가입구.혜화경찰서': (0.2571696958506562, '종로12')},
#     '종로5가': {   '동대문역사문화공원': (0.539504149707262, '407'),
#                 '방산시장.훈련원종합체육관': (0.539504149707262, '407'),
#                 '종로4가.종묘': (0.4457140404341607, 'N62B'),
#                 '종로5가.효제초등학교': (0.4207404082323984, '104'),
#                 '종로6가': (0.4457140404341607, 'N62B')},
#     '종로5가.광장시장': {   '원남동': (0.46044973615483, '106'),
#                      '종로4가.종묘': (0.54180908694339, '심야A21'),
#                      '종로5가.효제동.김상옥의거터': (0.4894193178547822, 'N31'),
#                      '종로5가.효제초등학교': (0.519857843824451, '8101'),
#                      '종로6가.동대문종합시장': (0.54180908694339, '심야A21'),
#                      '종로6가.종로신진시장': (0.4457140404341607, 'N62B')},
#     '종로5가.효제동.김상옥의거터': {   '방송통신대.이화장': (0.4894193178547822, 'N31'),
#                            '종로5가.광장시장': (0.4894193178547822, 'N31'),
#                            '종로5가.효제초등학교': (0.519857843824451, '8101')},
#     '종로5가.효제초등학교': {   '동대문': (0.4503739572516986, '7025'),
#                        '이화동(이화장)': (0.4503739572516986, '7025'),
#                        '종로5가': (0.4207404082323984, '104'),
#                        '종로5가.광장시장': (0.519857843824451, '8101'),
#                        '종로5가.효제동.김상옥의거터': (0.519857843824451, '8101')},
#     '종로5가역.광장시장': {   '종로5가역.중부교육지원청': (0.1963322146276322, '종로08'),
#                       '혜화경찰서': (0.1963322146276322, '종로08')},
#     '종로5가역.중부교육지원청': {   '동대문종합시장': (0.2343495384816965, '종로03'),
#                          '종로5가역.광장시장': (0.1963322146276322, '종로08'),
#                          '효제초교.연동교회.김마리아활동터': (0.1963322146276322, '종로08')},
#     '종로5가입구.혜화경찰서': {   '원남동': (0.2571696958506562, '종로12'),
#                         '종로4가.종묘공원': (0.2571696958506562, '종로12')},
#     '종로6가': {   '동대문역.흥인지문': (0.5645127097409511, 'N26A'),
#                 '동대문역사문화공원': (0.4457140404341607, 'N62B'),
#                 '종로5가': (0.4457140404341607, 'N62B')},
#     '종로6가.동대문종합시장': {   '동대문역.흥인지문': (0.54180908694339, '심야A21'),
#                         '동대문역사문화공원': (0.4251145420310577, 'N62'),
#                         '방산종합시장': (0.4484116233482251, '152'),
#                         '종로5가.광장시장': (0.54180908694339, '심야A21')},
#     '종로6가.종로신진시장': {   '동대문': (0.5645127097409511, 'N26A'),
#                        '동대문역사문화공원': (0.4457140404341607, 'N62B'),
#                        '종로5가.광장시장': (0.4457140404341607, 'N62B')},
#     '종로교회': {   '대우효령아파트': (0.4153633709103164, '641'),
#                 '서울교통공사': (0.3199187640797128, '서초17'),
#                 '주택단지': (0.3199187640797128, '서초17')},
#     '종로교회앞': {   '방배동대우효령아파트앞': (0.4153633709103164, '641'),
#                  '방현초교': (0.3363306668269706, '서초06'),
#                  '백산빌딩': (0.3199187640797128, '서초17'),
#                  '서울교통공사': (0.3199187640797128, '서초17')},
#     '종로구민회관.창신동두산아파트': {   '동묘앞역6번출구': (0.513190434415201, '142'),
#                            '동묘역': (0.2343495384816965, '종로03'),
#                            '창신3동주민센터': (0.513190434415201, '142'),
#                            '창신초등학교': (0.2343495384816965, '종로03')},
#     '종로도서관': {   '배화여중고': (0.1540396543626926, '종로05'),
#                  '활터앞': (0.1540396543626926, '종로05')},
#     '종로문화센터': {   '단군성전앞': (0.1540396543626926, '종로05'),
#                   '한국사회과학자료원': (0.1540396543626926, '종로05')},
#     '종로사약국': {   '외대역앞': (0.385355956457967, '273'),
#                  '이문동삼익아파트': (0.385355956457967, '273')},
#     '종로사우나': {   '운현궁': (0.1814262568133952, '종로01'),
#                  '인사동들머리.3.1독립선언터': (0.1814262568133952, '종로01')},
#     '종로센트레빌아파트': {   '쌍용아파트입구.창신역': (0.2343495384816965, '종로03'),
#                      '청룡사.보문파크뷰자이아파트': (0.2343495384816965, '종로03')},
#     '종로센트레빌후문.e편한세상보문아파트': {   '명신초.삼선푸르지오.힐스테이트': (0.2343495384816965, '종로03'),
#                          '판교반디유치원.복합문화단지': (0.67659443791276, '9409')},
#     '힐스테이트판교엘포레6단지': {   '판교더샵포레스트11단지': (0.67659443791276, '9409'),
#                          '힐스테이트판교엘포레6단지후문': (0.67659443791276, '9409')},
#     '힐스테이트판교엘포레6단지후문': {   '판교퍼스트힐푸르지오1단지': (0.67659443791276, '9409'),
#                            '힐스테이트판교엘포레6단지': (0.67659443791276, '9409')},
#     '힐탑': {   '감나무골공원': (0.2029491179348926, '종로06'),
#               '화인빌라': (0.2029491179348926, '종로06')},
#     '힐튼호텔': {   '남대문시장악세사리전문상가': (0.4535206198249369, '405'),
#                 '남산도서관.용산도서관': (0.4535206198249369, '405'),
#                 '백범광장': (0.4535206198249369, '405'),
#                 '숭례문남산방향': (0.4535206198249369, '405'),
#                 '원남동사거리': (1.5406725646804948, '01A'),
#                 '창덕궁.돈화문국악당': (1.5406725646804948, '01A')}}

# %%
nodes = {source for source in g}
nodes.update({dest for destinations in g.values() for dest in destinations})

# %%
n_nodes = len(nodes)
n_edges = sum((len(destinations) for destinations in g.values()))
print('n_nodes = {}, n_edges = {}'.format(n_nodes, n_edges))
# Out:
# n_nodes = 8517, n_edges = 29756

# %%
def initialize(start):
    cost = {node:(0 if node == start else 'inf') for node in nodes}
    return cost

cost = initialize('회기시장')

# %%
def update(cost):
    changed = False
    for from_, to_weight in g.items():
        for to_, weight in to_weight.items():
            if cost[to_] > cost[from_] + weight:
                before = cost[to_]
                after = cost[from_] + weight
                cost[to_] = after
                changed = True
                print('{} -> {} : {} -> {}'.format(from_, to_, before, after))
    return cost, changed

# %%
# def ford(start, destination, graph):
#     # 모든 노드의 초기 비용을 무한으로 설정하고, 시작 노드의 비용을 0으로 초기화
#     cost = {node: float('inf') for node in graph}
#     cost[start] = 0
#     previous_line = {node: None for node in graph}  # 이전 호선을 추적
#     path = {node: None for node in graph}  # 최단 경로 추적

#     # 그래프의 노드 수만큼 반복
#     for _ in range(len(graph) - 1):
#         updated = False
#         for u in graph:
#             for v, (dist, line) in graph[u].items():
#                 # 현재 노드 u에서 v로 가는데 필요한 호선 변경 비용을 계산
#                 transfer_penalty = 2.0 if previous_line[u] and previous_line[u] != line else 0
#                 new_cost = cost[u] + dist + transfer_penalty
#                 # 새로운 비용이 기존 비용보다 작으면 업데이트
#                 if cost[v] > new_cost:
#                     cost[v] = new_cost
#                     previous_line[v] = line
#                     path[v] = u
#                     updated = True
#         if not updated:  # 더 이상 업데이트가 없으면 종료
#             break

#     # 목적지에서 시작하여 역으로 최단 경로를 추적
#     shortest_path = []
#     current_node = destination
#     while current_node is not None:
#         shortest_path.append(current_node)
#         current_node = path[current_node]
#     shortest_path.reverse()

#     return shortest_path, cost[destination]

# start = '회기시장'
# destination = '동묘앞'
# print(ford(start, destination, g))
# y = ford(start, destination, g)[1]

# %%
def ford_with_lines(start, destination, graph):
    # 모든 노드의 초기 비용을 무한으로 설정하고, 시작 노드의 비용을 0으로 초기화
    cost = {node: float('inf') for node in graph}
    cost[start] = 0
    previous_line = {node: None for node in graph}  # 이전 호선을 추적
    path = {node: None for node in graph}  # 최단 경로 추적
    line_path = {node: None for node in graph}  # 경로 상의 호선을 추적

    # 그래프의 노드 수만큼 반복
    for _ in range(len(graph) - 1):
        updated = False
        for u in graph:
            for v, (dist, line) in graph[u].items():
                # 현재 노드 u에서 v로 가는데 필요한 호선 변경 비용을 계산
                transfer_penalty = 2.0 if previous_line[u] and previous_line[u] != line else 0
                new_cost = cost[u] + dist + transfer_penalty
                # 새로운 비용이 기존 비용보다 작으면 업데이트
                if cost[v] > new_cost:
                    cost[v] = new_cost
                    previous_line[v] = line
                    path[v] = u
                    line_path[v] = line
                    updated = True
        if not updated:  # 더 이상 업데이트가 없으면 종료
            break

    # 목적지에서 시작하여 역으로 최단 경로를 추적
    shortest_path = []
    current_node = destination
    current_line = line_path[destination]
    route_with_lines = []
    while current_node is not None:
        shortest_path.append(current_node)
        if current_line:
            route_with_lines.append((current_node, current_line))
        current_node = path[current_node]
        if current_node:
            current_line = line_path[current_node]
    shortest_path.reverse()
    route_with_lines.reverse()

    return shortest_path, cost[destination], route_with_lines

start = '회기시장'
destination = '동묘앞'
path, cost, route_with_lines = ford_with_lines(start, destination, g)
print("경로:", path)
print("비용:", cost)
print("노선 정보:", route_with_lines)
y = ford_with_lines(start, destination, g)[1]
# Out:
# 경로: ['회기시장', '우산빌딩앞', '서울성심병원', '청량리역환승센터', '청량리수산시장', '제기동역.서울약령시', '용두동사거리.한국의류시험연구원', '신설동역', '동묘앞']
# 비용: 5.27473268816611
# 노선 정보: [('우산빌딩앞', 'N13B'), ('서울성심병원', 'N13B'), ('청량리역환승센터', 'N72'), ('청량리수산시장', 'N72'), ('제기동역.서울약령시', 'N72'), ('용두동사거리.한국의류시험연구원', 'N72'), ('신설동역', 'N72'), ('동묘앞', 'N72')]

# %%
fares = []
def calculate_money(z, transport_type, bus_number=None):
    z = x + y
    if transport_type == '지하철':
        base_fare = 1400
    elif transport_type == '버스':
        if bus_number is not None:
            if len(str(bus_number)) == 3 and str(bus_number).isdigit():
                base_fare = 1500
            elif str(bus_number).startswith('N'):
                base_fare = 2500
            elif str(bus_number)[0].isalpha():  # 한글 포함 시 True
                base_fare = 1200
            else:
                base_fare = 1400
        else:
            base_fare = 1400  # 버스 번호 정보가 없는 경우 기본요금
    else:
        base_fare = 1400  # 기타 이동 수단의 기본요금

    # 추가 요금 계산
    additional_fare = 0
    if z > 10:
        if z <= 50:
            additional_fare += ((z - 10) // 5) * 100
        else:
            # 10km ~ 50km 까지의 추가요금
            additional_fare += 8 * 100
            # 50km 초과 거리에 대한 추가요금
            additional_fare += ((z - 50) // 8) * 100

    # 총 요금 계산
    total_fare = base_fare + additional_fare
    fares.append(total_fare)
    return sum(fares)

# 예시 사용법

# first_transport_type = '버스'  # 최초 이동 수단 종류
# total_fare = calculate_money(z, first_transport_type, 'N13B')
# print("총 요금:", total_fare)

# %%
month_cost = calculate_money(z, '지하철')
print(month_cost)
# Out:
# 2000.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 5100.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 8200.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 11300.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 14400.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 17500.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 20600.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 23700.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 26800.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 29900.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 33000.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 36100.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 39200.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 42300.0

# %%
month_cost = calculate_money(z, '버스', 'N13B')
print(month_cost)
# Out:
# 45400.0

# %%
age = 39
is_low_income = 0
ride_number = len(fares)

#기후동행카드
def calculate_gihoo_cost(age):
    if age > 34:  # 일반권
        gh_cost = 62000
    elif 19 <= age <= 34:  # 청년권
        gh_cost = 55000
    else:
        gh_cost = None  # 기타 권종에 대한 처리를 추가해야 합니다. 예를 들어 어린이 요금 등

    return gh_cost

# Main function to calculate the basic cost of a K-pass based on age and income status
def calculate_kpass_cost(age, is_low_income, month_cost):
    if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
    if age > 34:
        discount_rate = 0.53 if is_low_income == 1 else 0.20  # Low income or regular, older adults
    elif 19 <= age <= 34:
        discount_rate = 0.53 if is_low_income == 1 else 0.30  # Low income or regular, young adults
    else:
        discount_rate = 0  # No discount for those under 19

    kpass_cost = month_cost * (1 - discount_rate)
    return kpass_cost



#k-pass 신한카드- 신용카드
def calculate_kpass_shcredit_cost(month_cost):
  if ride_number < 15:
      print("ride_number는 15 이상이어야 합니다.")
  kpass_shcredit_cost = month_cost * 0.9
  return kpass_shcredit_cost
#k-pass 신한카드- 체크카드
def calculate_kpass_shcheck_cost(month_cost):
  if ride_number < 15:
       print("ride_number는 15 이상이어야 합니다.")
  kpass_shcheck_cost = month_cost * 0.9
  return kpass_shcheck_cost

#k-pass 국민카드- 신용카드
def calculate_kpass_kbcredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_kbcredit_cost = month_cost * 0.9
  return kpass_kbcredit_cost
#k-pass 국민카드- 체크카드
def calculate_kpass_kbcheck_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_kbcheck_cost = month_cost * 0.9
  return kpass_kbcheck_cost

#k-pass 삼성카드- 신용카드
def calculate_kpass_sscredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_sscredit_cost = month_cost * 0.9
  return kpass_sscredit_cost

  #k-pass 삼성카드- 체크카드
def calculate_kpass_sscheck_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_sscheck_cost = month_cost * 0.9
  return kpass_sscheck_cost

  #k-pass 우리카드- 신용카드
def calculate_kpass_wrcredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_wrcredit_cost = month_cost * 0.9
  return kpass_wrcredit_cost

  #k-pass 우리카드- 체크카드
def calculate_kpass_wrcheck_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_wrcheck_cost = month_cost - 3000
  return kpass_wrcheck_cost

  #k-pass 농협카드- 신용카드
def calculate_kpass_nhcredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_nhcredit_cost = month_cost * 0.9
  return kpass_nhcredit_cost

  #k-pass 농협카드- 체크카드
def calculate_kpass_nhcheck_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_nhcheck_cost = month_cost * 0.95
  return kpass_nhcheck_cost

  #k-pass 하나카드- 신용카드
def calculate_kpass_hncredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_hncredit_cost = month_cost * 0.9
  return kpass_hncredit_cost

  #k-pass 농협카드- 체크카드
def calculate_kpass_hncheck_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_hncheck_cost = month_cost * 0.9
  return kpass_hncheck_cost

  #k-pass 케이뱅크- 체크카드
def calculate_kpass_kcheck_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  if month_cost>50000:
    kpass_kcheck_cost = month_cost - 3000
  else:
        kpass_kcheck_cost = month_cost
  return kpass_kcheck_cost

  #k-pass-BC바로카드-신용카드
def calculate_kpass_bccredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_bccredit_cost = month_cost * 0.85
  return kpass_bccredit_cost

  #k-pass-현대카드-신용카드
def calculate_kpass_hdcredit_cost(month_cost):
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_hdcredit_cost = month_cost * 0.90
  return kpass_hdcredit_cost

  #k-pass-IBK-신용카드
def calculate_kpass_ibkcredit_cost(month_cost, ride_number): #ride_number은 대중교통이용횟수
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  if month_cost >= 200000 and month_cost<500000:
    kpass_ibkcredit_cost = month_cost - (100*ride_number)
  elif month_cost >= 500000:
    kpass_ibkcredit_cost = month_cost - (200*ride_number)



  return kpass_ibkcredit_cost

  #k-pass-IBK-신용카드
def calculate_kpass_ibkcheck_cost(month_cost, ride_number): #ride_number은 대중교통이용횟수
  if ride_number < 15:
        print("ride_number는 15 이상이어야 합니다.")
  kpass_ibkcheck_cost = month_cost - (100*ride_number)
  return kpass_ibkcheck_cost

  # 각 카드별 총 비용 계산
shcreditcost = calculate_kpass_cost(age, is_low_income, month_cost) +calculate_kpass_shcheck_cost(month_cost) - month_cost
shcheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_shcheck_cost(month_cost) - month_cost
kbcreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_kbcredit_cost(month_cost)- month_cost
kbcheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_kbcheck_cost(month_cost)- month_cost
sscreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_sscredit_cost(month_cost)- month_cost
sscheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_sscheck_cost(month_cost)- month_cost
wrcreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_wrcredit_cost(month_cost)- month_cost
wrcheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_wrcheck_cost(month_cost)- month_cost
nhcreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_nhcredit_cost(month_cost)- month_cost
nhcheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_nhcheck_cost(month_cost)- month_cost
hncreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_hncredit_cost(month_cost)- month_cost
hncheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_hncheck_cost(month_cost)- month_cost
kcheckcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_kcheck_cost(month_cost)- month_cost
bccreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_bccredit_cost(month_cost)- month_cost
hdcreditcost = calculate_kpass_cost(age, is_low_income, month_cost) + calculate_kpass_hdcredit_cost(month_cost)- month_cost
ghcost = calculate_gihoo_cost(age)

# 각 항목의 총 비용을 사전에 저장
costs = {
    "shcreditcost": shcreditcost,
    "shcheckcost": shcheckcost,
    "kbcreditcost": kbcreditcost,
    "nhcheckcost": nhcheckcost,
    "kbcheckcost": kbcheckcost,
    "sscreditcost": sscreditcost,
    "sscheckcost": sscheckcost,
    "wrcreditcost": wrcreditcost,
    "wrcheckcost": wrcheckcost,
    "nhcreditcost": nhcreditcost,
    "hncreditcost": hncreditcost,
    "hncheckcost": hncheckcost,
    "kcheckcost": kcheckcost,
    "bccreditcost": bccreditcost,
    "hdcreditcost": hdcreditcost,
    "ghcost" : ghcost
}

sorted_costs_lowest = sorted(costs.items(), key=lambda x: x[1])[:3]
sorted_costs_highest = sorted(costs.items(), key=lambda x: x[1], reverse=True)[:3]
if ride_number >= 15:
  print("가장 낮은 비용 3개:")
  for item in sorted_costs_lowest:
    print(item)

if ride_number >= 15:
  print("\n가장 높은 비용 3개:")
  for item in sorted_costs_highest:
    print(item)
# Out:
# 가장 낮은 비용 3개:
# ('bccreditcost', 29510.0)
# ('shcreditcost', 31780.0)
# ('shcheckcost', 31780.0)
#
# 가장 높은 비용 3개:
# ('ghcost', 62000)
# ('kcheckcost', 36320.0)
# ('nhcheckcost', 34050.0)
